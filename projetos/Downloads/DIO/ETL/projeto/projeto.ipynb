# %%
# Aula 3
# url :  https://dados.gov.br/dataset/ocorrencias-aeronauticas-da-aviacao-civil-brasileira
#     Objetivos:
#     -> Dsenvolvimento
#         1. Extração
#         2. Validação 
#         3. Limpeza
#         4. Trasnformação

# %%
# pip install pandera

# %%
import pandas as pd
import pandera as pa # etapa 2: validação de dados

# %%
# Etapa 1 -> extração de dados

# %%
dataframe = pd.read_csv("ocorrencia.csv", sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True)
dataframe.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
# 5              39807               39807               39807
# 6              40215               40215               40215
# 7              39707               39707               39707
# 8              39156               39156               39156
# 9              39711               39711               39711
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# ...

# %%
schema =  pa.DataFrameSchema(
    columns = {
        "codigo": pa.Column(pa.Int, required=False)
        "codigo_ocorrencia":pa.Column(pa.Int),
        "codigo_ocorrencia2":pa.Column(pa.Int),
        "ocorrencia_classificacao":pa.Column(pa.String),
        "ocorrencia_cidade":pa.Column(pa.String),
        "ocorrencia_uf":pa.Column(pa.String, pa.Check.str_length(2,2)),
        "ocorrencia_aerodromo":pa.Column(pa.String),
        "ocorrencia_dia":pa.Column(pa.DateTime),
        "ocorrencia_hora":pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=True),
        "total_recomendacoes":pa.Column(pa.Int)
    }
) 
# etapa 2 : validação dados
# Out:
#   File "/tmp/ipykernel_49/2041315520.py", line 4
#     "codigo_ocorrencia":pa.Column(pa.Int),
#     ^
# SyntaxError: invalid syntax

# %%
schema.validate(dataframe) # etapa 2 : validação dados
# Out:
# ---------------------------------------------------------------------------
# SchemaError                               Traceback (most recent call last)
# /tmp/ipykernel_49/1727859299.py in <module>
# ----> 1 schema.validate(dataframe) # etapa 2 : validação dados
#
# /opt/conda/lib/python3.9/site-packages/pandera/schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     483             return check_obj.pandera.add_schema(self)
#     484
# --> 485         return self._validate(
#     486             check_obj=check_obj,
#     487             head=head,
#
# /opt/conda/lib/python3.9/site-packages/pandera/schemas.py in _validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     657                 check_results.append(check_utils.is_table(result))
#     658             except errors.SchemaError as err:
# --> 659                 error_handler.collect_error("schema_component_check", err)
# ...

# %%
dataframe.dtypes
# Out:
# codigo_ocorrencia                          int64
# codigo_ocorrencia1                         int64
# codigo_ocorrencia2                         int64
# codigo_ocorrencia3                         int64
# codigo_ocorrencia4                         int64
# ocorrencia_classificacao                  object
# ocorrencia_latitude                       object
# ocorrencia_longitude                      object
# ocorrencia_cidade                         object
# ocorrencia_uf                             object
# ocorrencia_pais                           object
# ocorrencia_aerodromo                      object
# ocorrencia_dia                    datetime64[ns]
# ocorrencia_hora                           object
# investigacao_aeronave_liberada            object
# investigacao_status                       object
# divulgacao_relatorio_numero               object
# divulgacao_relatorio_publicado            object
# divulgacao_dia_publicacao                 object
# ...

# %%
dataframe.ocorrencia_dia.dt.month
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 6109    8
# 6110    8
# 6111    8
# 6112    8
# 6113    8
# Name: ocorrencia_dia, Length: 6114, dtype: int64

# %%
df = pd.DataFrame(dataframe, columns = ['codigo_ocorrencia', 'ocorrencia_classificacao', 'ocorrencia_hora'])
df
# Out:
#       codigo_ocorrencia ocorrencia_classificacao ocorrencia_hora
# 0                 40211                INCIDENTE        12:00:00
# 1                 40349                INCIDENTE        11:05:00
# 2                 40351                INCIDENTE        03:00:00
# 3                 39527                 ACIDENTE        17:30:00
# 4                 40324                INCIDENTE        19:25:00
# ...                 ...                      ...             ...
# 6109              80245                INCIDENTE        15:05:00
# 6110              80247                INCIDENTE        02:30:00
# 6111              80251                INCIDENTE        15:45:00
# 6112              80257                 ACIDENTE        16:00:00
# 6113              80259                INCIDENTE        12:45:00
#
# [6114 rows x 3 columns]

# %%
# Etapa 1 -> validação de dados

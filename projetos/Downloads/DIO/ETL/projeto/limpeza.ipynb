# %%
# Aula 3
# url :  https://dados.gov.br/dataset/ocorrencias-aeronauticas-da-aviacao-civil-brasileira
#     Objetivos:
#     -> Dsenvolvimento
#         1. Extração
#         2. Validação 
#         3. Limpeza
#         4. Trasnformação

# %%
import pandas as pd

# %%
dataframe = pd.read_csv("ocorrencia.csv", sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True)
dataframe.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
# 5              39807               39807               39807
# 6              40215               40215               40215
# 7              39707               39707               39707
# 8              39156               39156               39156
# 9              39711               39711               39711
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
# 4               40324               40324                INCIDENTE
# 5               39807               39807                INCIDENTE
# 6               40215               40215                INCIDENTE
# 7               39707               39707          INCIDENTE GRAVE
# 8               39156               39156          INCIDENTE GRAVE
# 9               39711               39711          INCIDENTE GRAVE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 0                 ***                  ***      RIO DE JANEIRO            RJ
# 1                 NaN                  NaN               BELÉM            PA
# 2                 NaN                  NaN      RIO DE JANEIRO            RJ
# 3      -13.1066666667       -55.9930555556  LUCAS DO RIO VERDE            MT
# 4                 NaN                  NaN             PELOTAS            RS
# 5                 ***                  ***            SALVADOR            BA
# 6                 ***                  ***               COARI            AM
# 7       -6.5319444444       -64.3805555556            CANUTAMA            AM
# 8      -15.2402777778       -59.3541666667            CASCAVEL            PR
# 9                 ***                  ***       PARÁ DE MINAS            MG
#
#    ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 0  ...     2010-01-03        12:00:00                            SIM
# 1  ...     2010-01-03        11:05:00                            SIM
# 2  ...     2010-01-03        03:00:00                            SIM
# 3  ...     2010-01-04        17:30:00                            SIM
# 4  ...     2010-01-05        19:25:00                            SIM
# 5  ...     2010-01-06        17:53:00                            ***
# 6  ...     2010-01-07        18:40:00                            SIM
# 7  ...     2010-01-09        12:30:00                            SIM
# 8  ...     2010-01-10        23:15:00                            SIM
# 9  ...     2010-01-10        20:00:00                            ***
#
#   investigacao_status divulgacao_relatorio_numero  \
# 0          FINALIZADA                         ***
# 1          FINALIZADA                         NaN
# 2          FINALIZADA                         NaN
# 3          FINALIZADA           A-539/CENIPA/2018
# 4          FINALIZADA                         NaN
# 5                 NaN                         NaN
# 6          FINALIZADA                         NaN
# 7          FINALIZADA          IG-028/CENIPA/2011
# 8          FINALIZADA           I-004/CENIPA/2011
# 9                 NaN                         NaN
#
#   divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 0                            NÃO                       NaN
# 1                            NÃO                       NaN
# 2                            NÃO                       NaN
# 3                            SIM                2019-10-28
# 4                            NÃO                       NaN
# 5                            NÃO                       NaN
# 6                            NÃO                       NaN
# 7                            SIM                2011-07-21
# 8                            SIM                2011-06-30
# 9                            NÃO                       NaN
#
#   total_recomendacoes total_aeronaves_envolvidas  ocorrencia_saida_pista
# 0                   0                          1                     NÃO
# 1                   0                          1                     NÃO
# 2                   0                          1                     NÃO
# 3                   0                          1                     NÃO
# 4                   0                          1                     NÃO
# 5                   0                          1                     NÃO
# 6                   0                          1                     SIM
# 7                   3                          1                     NÃO
# 8                   2                          1                     NÃO
# 9                   0                          1                     NÃO
#
# [10 rows x 22 columns]

# %%
dataframe.loc[1, 'ocorrencia_cidade']
# Out:
# 'BELÉM'

# %%
dataframe.loc[3]
# Out:
# codigo_ocorrencia                               39527
# codigo_ocorrencia1                              39527
# codigo_ocorrencia2                              39527
# codigo_ocorrencia3                              39527
# codigo_ocorrencia4                              39527
# ocorrencia_classificacao                     ACIDENTE
# ocorrencia_latitude                    -13.1066666667
# ocorrencia_longitude                   -55.9930555556
# ocorrencia_cidade                  LUCAS DO RIO VERDE
# ocorrencia_uf                                      MT
# ocorrencia_pais                                BRASIL
# ocorrencia_aerodromo                             ****
# ocorrencia_dia                    2010-01-04 00:00:00
# ocorrencia_hora                              17:30:00
# investigacao_aeronave_liberada                    SIM
# investigacao_status                        FINALIZADA
# divulgacao_relatorio_numero         A-539/CENIPA/2018
# divulgacao_relatorio_publicado                    SIM
# divulgacao_dia_publicacao                  2019-10-28
# total_recomendacoes                                 0
# total_aeronaves_envolvidas                          1
# ocorrencia_saida_pista                            NÃO
# Name: 3, dtype: object

# %%
dataframe.loc[1:3]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 1                 NaN                  NaN               BELÉM            PA
# 2                 NaN                  NaN      RIO DE JANEIRO            RJ
# 3      -13.1066666667       -55.9930555556  LUCAS DO RIO VERDE            MT
#
#    ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 1  ...     2010-01-03        11:05:00                            SIM
# 2  ...     2010-01-03        03:00:00                            SIM
# 3  ...     2010-01-04        17:30:00                            SIM
#
#   investigacao_status divulgacao_relatorio_numero  \
# 1          FINALIZADA                         NaN
# 2          FINALIZADA                         NaN
# 3          FINALIZADA           A-539/CENIPA/2018
#
#   divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 1                            NÃO                       NaN
# 2                            NÃO                       NaN
# 3                            SIM                2019-10-28
#
#   total_recomendacoes total_aeronaves_envolvidas  ocorrencia_saida_pista
# 1                   0                          1                     NÃO
# 2                   0                          1                     NÃO
# 3                   0                          1                     NÃO
#
# [3 rows x 22 columns]

# %%
dataframe.loc[[10,40]]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 10              39789               39789               39789
# 40              39158               39158               39158
#
#     codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 10               39789               39789                INCIDENTE
# 40               39158               39158                INCIDENTE
#
#    ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 10                 NaN                  NaN  SÃO PEDRO DO SUL            RS
# 40                 ***                  ***             BELÉM            PA
#
#     ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 10  ...     2010-01-10        21:30:00                            ***
# 40  ...     2010-01-28        16:00:00                            SIM
#
#    investigacao_status divulgacao_relatorio_numero  \
# 10                 NaN                         NaN
# 40          FINALIZADA                         NaN
#
#    divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 10                            NÃO                       NaN
# 40                            NÃO                       NaN
#
#    total_recomendacoes total_aeronaves_envolvidas  ocorrencia_saida_pista
# 10                   0                          1                     NÃO
# 40                   0                          1                     NÃO
#
# [2 rows x 22 columns]

# %%
dataframe.loc[:,'ocorrencia_cidade']
# Out:
# 0           RIO DE JANEIRO
# 1                    BELÉM
# 2           RIO DE JANEIRO
# 3       LUCAS DO RIO VERDE
# 4                  PELOTAS
#                ...
# 6109                RECIFE
# 6110           PORTO VELHO
# 6111                 BELÉM
# 6112            DOM AQUINO
# 6113              CAMPINAS
# Name: ocorrencia_cidade, Length: 6114, dtype: object

# %%
dataframe.codigo_ocorrencia.is_unique
# Out:
# True

# %%
dataframe.ocorrencia_uf.is_unique
# Out:
# False

# %%
dataframe.set_index('codigo_ocorrencia')
# Out:
#                    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# codigo_ocorrencia
# 40211                           40211               40211               40211
# 40349                           40349               40349               40349
# 40351                           40351               40351               40351
# 39527                           39527               39527               39527
# 40324                           40324               40324               40324
# ...                               ...                 ...                 ...
# 80245                           80245               80245               80245
# 80247                           80247               80247               80247
# 80251                           80251               80251               80251
# 80257                           80257               80257               80257
# 80259                           80259               80259               80259
#
#                    codigo_ocorrencia4 ocorrencia_classificacao  \
# codigo_ocorrencia
# 40211                           40211                INCIDENTE
# 40349                           40349                INCIDENTE
# 40351                           40351                INCIDENTE
# 39527                           39527                 ACIDENTE
# 40324                           40324                INCIDENTE
# ...                               ...                      ...
# 80245                           80245                INCIDENTE
# 80247                           80247                INCIDENTE
# 80251                           80251                INCIDENTE
# 80257                           80257                 ACIDENTE
# 80259                           80259                INCIDENTE
#
#                   ocorrencia_latitude ocorrencia_longitude  \
# codigo_ocorrencia
# 40211                             ***                  ***
# 40349                             NaN                  NaN
# 40351                             NaN                  NaN
# 39527                  -13.1066666667       -55.9930555556
# 40324                             NaN                  NaN
# ...                               ...                  ...
# 80245                        -8.12638            -34.92277
# 80247                 -8.713611111111      -63.90277777777
# 80251                 -1.384722222222      -48.47888888888
# 80257                      -15.430833           -54.699722
# 80259                 -23.00694444444      -47.13444444444
#
#                     ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# codigo_ocorrencia                                                    ...
# 40211                  RIO DE JANEIRO            RJ          BRASIL  ...
# 40349                           BELÉM            PA          BRASIL  ...
# 40351                  RIO DE JANEIRO            RJ          BRASIL  ...
# 39527              LUCAS DO RIO VERDE            MT          BRASIL  ...
# 40324                         PELOTAS            RS          BRASIL  ...
# ...                               ...           ...             ...  ...
# 80245                          RECIFE            PE          BRASIL  ...
# 80247                     PORTO VELHO            RO          BRASIL  ...
# 80251                           BELÉM            PA          BRASIL  ...
# 80257                      DOM AQUINO            MT          BRASIL  ...
# 80259                        CAMPINAS            SP          BRASIL  ...
#
#                   ocorrencia_dia ocorrencia_hora  \
# codigo_ocorrencia
# 40211                 2010-01-03        12:00:00
# 40349                 2010-01-03        11:05:00
# 40351                 2010-01-03        03:00:00
# 39527                 2010-01-04        17:30:00
# 40324                 2010-01-05        19:25:00
# ...                          ...             ...
# 80245                 2021-08-15        15:05:00
# 80247                 2021-08-16        02:30:00
# 80251                 2021-08-17        15:45:00
# 80257                 2021-08-18        16:00:00
# 80259                 2021-08-18        12:45:00
#
#                   investigacao_aeronave_liberada investigacao_status  \
# codigo_ocorrencia
# 40211                                        SIM          FINALIZADA
# 40349                                        SIM          FINALIZADA
# 40351                                        SIM          FINALIZADA
# 39527                                        SIM          FINALIZADA
# 40324                                        SIM          FINALIZADA
# ...                                          ...                 ...
# 80245                                        SIM          FINALIZADA
# 80247                                        SIM          FINALIZADA
# 80251                                        SIM          FINALIZADA
# 80257                                        SIM          FINALIZADA
# 80259                                        SIM          FINALIZADA
#
#                   divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# codigo_ocorrencia
# 40211                                     ***                            NÃO
# 40349                                     NaN                            NÃO
# 40351                                     NaN                            NÃO
# 39527                       A-539/CENIPA/2018                            SIM
# 40324                                     NaN                            NÃO
# ...                                       ...                            ...
# 80245                                     ***                            NÃO
# 80247                                     ***                            NÃO
# 80251                                     ***                            NÃO
# 80257                                     ***                            NÃO
# 80259                                     ***                            NÃO
#
#                   divulgacao_dia_publicacao total_recomendacoes  \
# codigo_ocorrencia
# 40211                                   NaN                   0
# 40349                                   NaN                   0
# 40351                                   NaN                   0
# 39527                            2019-10-28                   0
# 40324                                   NaN                   0
# ...                                     ...                 ...
# 80245                                   NaN                   0
# 80247                                   NaN                   0
# 80251                                   NaN                   0
# 80257                                   NaN                   0
# 80259                                   NaN                   0
#
#                    total_aeronaves_envolvidas  ocorrencia_saida_pista
# codigo_ocorrencia
# 40211                                       1                     NÃO
# 40349                                       1                     NÃO
# 40351                                       1                     NÃO
# 39527                                       1                     NÃO
# 40324                                       1                     NÃO
# ...                                       ...                     ...
# 80245                                       1                     NÃO
# 80247                                       1                     NÃO
# 80251                                       1                     NÃO
# 80257                                       1                     NÃO
# 80259                                       1                     NÃO
#
# [6114 rows x 21 columns]

# %%
dataframe.set_index('codigo_ocorrencia', inplace=True)

# %%
dataframe.head(10)
# Out:
#                    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# codigo_ocorrencia
# 40211                           40211               40211               40211
# 40349                           40349               40349               40349
# 40351                           40351               40351               40351
# 39527                           39527               39527               39527
# 40324                           40324               40324               40324
# 39807                           39807               39807               39807
# 40215                           40215               40215               40215
# 39707                           39707               39707               39707
# 39156                           39156               39156               39156
# 39711                           39711               39711               39711
#
#                    codigo_ocorrencia4 ocorrencia_classificacao  \
# codigo_ocorrencia
# 40211                           40211                INCIDENTE
# 40349                           40349                INCIDENTE
# 40351                           40351                INCIDENTE
# 39527                           39527                 ACIDENTE
# 40324                           40324                INCIDENTE
# 39807                           39807                INCIDENTE
# 40215                           40215                INCIDENTE
# 39707                           39707          INCIDENTE GRAVE
# 39156                           39156          INCIDENTE GRAVE
# 39711                           39711          INCIDENTE GRAVE
#
#                   ocorrencia_latitude ocorrencia_longitude  \
# codigo_ocorrencia
# 40211                             ***                  ***
# 40349                               0                    0
# 40351                               0                    0
# 39527                  -13.1066666667       -55.9930555556
# 40324                               0                    0
# 39807                             ***                  ***
# 40215                             ***                  ***
# 39707                   -6.5319444444       -64.3805555556
# 39156                  -15.2402777778       -59.3541666667
# 39711                             ***                  ***
#
#                     ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# codigo_ocorrencia                                                    ...
# 40211                  RIO DE JANEIRO            RJ          BRASIL  ...
# 40349                           BELÉM            PA          BRASIL  ...
# 40351                  RIO DE JANEIRO            RJ          BRASIL  ...
# 39527              LUCAS DO RIO VERDE            MT          BRASIL  ...
# 40324                         PELOTAS            RS          BRASIL  ...
# 39807                        SALVADOR            BA          BRASIL  ...
# 40215                           COARI            AM          BRASIL  ...
# 39707                        CANUTAMA            AM          BRASIL  ...
# 39156                        CASCAVEL            PR          BRASIL  ...
# 39711                   PARÁ DE MINAS            MG          BRASIL  ...
#
#                   ocorrencia_dia ocorrencia_hora  \
# codigo_ocorrencia
# 40211                 2010-01-03        12:00:00
# 40349                 2010-01-03        11:05:00
# 40351                 2010-01-03        03:00:00
# 39527                 2010-01-04        17:30:00
# 40324                 2010-01-05        19:25:00
# 39807                 2010-01-06        17:53:00
# 40215                 2010-01-07        18:40:00
# 39707                 2010-01-09        12:30:00
# 39156                 2010-01-10        23:15:00
# 39711                 2010-01-10        20:00:00
#
#                   investigacao_aeronave_liberada investigacao_status  \
# codigo_ocorrencia
# 40211                                        SIM          FINALIZADA
# 40349                                        SIM          FINALIZADA
# 40351                                        SIM          FINALIZADA
# 39527                                        SIM          FINALIZADA
# 40324                                        SIM          FINALIZADA
# 39807                                        ***                   0
# 40215                                        SIM          FINALIZADA
# 39707                                        SIM          FINALIZADA
# 39156                                        SIM          FINALIZADA
# 39711                                        ***                   0
#
#                   divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# codigo_ocorrencia
# 40211                                     ***                            NÃO
# 40349                                       0                            NÃO
# 40351                                       0                            NÃO
# 39527                       A-539/CENIPA/2018                            SIM
# 40324                                       0                            NÃO
# 39807                                       0                            NÃO
# 40215                                       0                            NÃO
# 39707                      IG-028/CENIPA/2011                            SIM
# 39156                       I-004/CENIPA/2011                            SIM
# 39711                                       0                            NÃO
#
#                   divulgacao_dia_publicacao total_recomendacoes  \
# codigo_ocorrencia
# 40211                                     0                   0
# 40349                                     0                   0
# 40351                                     0                   0
# 39527                            2019-10-28                   0
# 40324                                     0                   0
# 39807                                     0                   0
# 40215                                     0                   0
# 39707                            2011-07-21                   3
# 39156                            2011-06-30                   2
# 39711                                     0                   0
#
#                    total_aeronaves_envolvidas  ocorrencia_saida_pista
# codigo_ocorrencia
# 40211                                       1                     NÃO
# 40349                                       1                     NÃO
# 40351                                       1                     NÃO
# 39527                                       1                     NÃO
# 40324                                       1                     NÃO
# 39807                                       1                     NÃO
# 40215                                       1                     SIM
# 39707                                       1                     NÃO
# 39156                                       1                     NÃO
# 39711                                       1                     NÃO
#
# [10 rows x 21 columns]

# %%
dataframe.loc[40211]
# Out:
# codigo_ocorrencia1                              40211
# codigo_ocorrencia2                              40211
# codigo_ocorrencia3                              40211
# codigo_ocorrencia4                              40211
# ocorrencia_classificacao                    INCIDENTE
# ocorrencia_latitude                               ***
# ocorrencia_longitude                              ***
# ocorrencia_cidade                      RIO DE JANEIRO
# ocorrencia_uf                                      RJ
# ocorrencia_pais                                BRASIL
# ocorrencia_aerodromo                                0
# ocorrencia_dia                    2010-01-03 00:00:00
# ocorrencia_hora                              12:00:00
# investigacao_aeronave_liberada                    SIM
# investigacao_status                        FINALIZADA
# divulgacao_relatorio_numero                       ***
# divulgacao_relatorio_publicado                    NÃO
# divulgacao_dia_publicacao                           0
# total_recomendacoes                                 0
# total_aeronaves_envolvidas                          1
# ocorrencia_saida_pista                            NÃO
# Name: 40211, dtype: object

# %%
dataframe.reset_index(drop=True, inplace=True)

# %%
dataframe.head()
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               40211               40211               40211
# 1               40349               40349               40349
# 2               40351               40351               40351
# 3               39527               39527               39527
# 4               40324               40324               40324
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               40211                INCIDENTE                 ***
# 1               40349                INCIDENTE                 NaN
# 2               40351                INCIDENTE                 NaN
# 3               39527                 ACIDENTE      -13.1066666667
# 4               40324                INCIDENTE                 NaN
#
#   ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                  ***      RIO DE JANEIRO            RJ          BRASIL  ...
# 1                  NaN               BELÉM            PA          BRASIL  ...
# 2                  NaN      RIO DE JANEIRO            RJ          BRASIL  ...
# 3       -55.9930555556  LUCAS DO RIO VERDE            MT          BRASIL  ...
# 4                  NaN             PELOTAS            RS          BRASIL  ...
#
#   ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 0     2010-01-03        12:00:00                            SIM
# 1     2010-01-03        11:05:00                            SIM
# 2     2010-01-03        03:00:00                            SIM
# 3     2010-01-04        17:30:00                            SIM
# 4     2010-01-05        19:25:00                            SIM
#
#   investigacao_status divulgacao_relatorio_numero  \
# 0          FINALIZADA                         ***
# 1          FINALIZADA                         NaN
# 2          FINALIZADA                         NaN
# 3          FINALIZADA           A-539/CENIPA/2018
# 4          FINALIZADA                         NaN
#
#   divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 0                            NÃO                       NaN
# 1                            NÃO                       NaN
# 2                            NÃO                       NaN
# 3                            SIM                2019-10-28
# 4                            NÃO                       NaN
#
#   total_recomendacoes  total_aeronaves_envolvidas  ocorrencia_saida_pista
# 0                   0                           1                     NÃO
# 1                   0                           1                     NÃO
# 2                   0                           1                     NÃO
# 3                   0                           1                     NÃO
# 4                   0                           1                     NÃO
#
# [5 rows x 21 columns]

# %%
dataframe.loc[0, 'ocorrencia_aerodromo']
# Out:
# '****'

# %%
dataframe.loc[0, 'ocorrencia_aerodromo'] = ''

# %%
dataframe.loc[0, 'ocorrencia_aerodromo']
# Out:
# ''

# %%
dataframe.loc[0]
# Out:
# codigo_ocorrencia1                              40211
# codigo_ocorrencia2                              40211
# codigo_ocorrencia3                              40211
# codigo_ocorrencia4                              40211
# ocorrencia_classificacao                    INCIDENTE
# ocorrencia_latitude                               ***
# ocorrencia_longitude                              ***
# ocorrencia_cidade                      RIO DE JANEIRO
# ocorrencia_uf                                      RJ
# ocorrencia_pais                                BRASIL
# ocorrencia_aerodromo
# ocorrencia_dia                    2010-01-03 00:00:00
# ocorrencia_hora                              12:00:00
# investigacao_aeronave_liberada                    SIM
# investigacao_status                        FINALIZADA
# divulgacao_relatorio_numero                       ***
# divulgacao_relatorio_publicado                    NÃO
# divulgacao_dia_publicacao                         NaN
# total_recomendacoes                                 0
# total_aeronaves_envolvidas                          1
# ocorrencia_saida_pista                            NÃO
# Name: 0, dtype: object

# %%
dataframe.loc[1] = 20

# %%
dataframe.head(2)
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               40211               40211               40211
# 1                  20                  20                  20
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               40211                INCIDENTE                 ***
# 1                  20                       20                  20
#
#   ocorrencia_longitude ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                  ***    RIO DE JANEIRO            RJ          BRASIL  ...
# 1                   20                20            20              20  ...
#
#         ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 0  2010-01-03 00:00:00        12:00:00                            SIM
# 1                   20              20                             20
#
#   investigacao_status divulgacao_relatorio_numero  \
# 0          FINALIZADA                         ***
# 1                  20                          20
#
#   divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 0                            NÃO                       NaN
# 1                             20                        20
#
#   total_recomendacoes  total_aeronaves_envolvidas  ocorrencia_saida_pista
# 0                   0                           1                     NÃO
# 1                  20                          20                      20
#
# [2 rows x 21 columns]

# %%
dataframe.loc[:,'ocorrencia_latitude'] = 10

# %%
dataframe.head(10)
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               40211               40211               40211
# 1                  20                  20                  20
# 2               40351               40351               40351
# 3               39527               39527               39527
# 4               40324               40324               40324
# 5               39807               39807               39807
# 6               40215               40215               40215
# 7               39707               39707               39707
# 8               39156               39156               39156
# 9               39711               39711               39711
#
#    codigo_ocorrencia4 ocorrencia_classificacao  ocorrencia_latitude  \
# 0               40211                INCIDENTE                   10
# 1                  20                       20                   10
# 2               40351                INCIDENTE                   10
# 3               39527                 ACIDENTE                   10
# 4               40324                INCIDENTE                   10
# 5               39807                INCIDENTE                   10
# 6               40215                INCIDENTE                   10
# 7               39707          INCIDENTE GRAVE                   10
# 8               39156          INCIDENTE GRAVE                   10
# 9               39711          INCIDENTE GRAVE                   10
#
#   ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                  ***      RIO DE JANEIRO            RJ          BRASIL  ...
# 1                   20                  20            20              20  ...
# 2                  NaN      RIO DE JANEIRO            RJ          BRASIL  ...
# 3       -55.9930555556  LUCAS DO RIO VERDE            MT          BRASIL  ...
# 4                  NaN             PELOTAS            RS          BRASIL  ...
# 5                  ***            SALVADOR            BA          BRASIL  ...
# 6                  ***               COARI            AM          BRASIL  ...
# 7       -64.3805555556            CANUTAMA            AM          BRASIL  ...
# 8       -59.3541666667            CASCAVEL            PR          BRASIL  ...
# 9                  ***       PARÁ DE MINAS            MG          BRASIL  ...
#
#         ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 0  2010-01-03 00:00:00        12:00:00                            SIM
# 1                   20              20                             20
# 2  2010-01-03 00:00:00        03:00:00                            SIM
# 3  2010-01-04 00:00:00        17:30:00                            SIM
# 4  2010-01-05 00:00:00        19:25:00                            SIM
# 5  2010-01-06 00:00:00        17:53:00                            ***
# 6  2010-01-07 00:00:00        18:40:00                            SIM
# 7  2010-01-09 00:00:00        12:30:00                            SIM
# 8  2010-01-10 00:00:00        23:15:00                            SIM
# 9  2010-01-10 00:00:00        20:00:00                            ***
#
#   investigacao_status divulgacao_relatorio_numero  \
# 0          FINALIZADA                         ***
# 1                  20                          20
# 2          FINALIZADA                         NaN
# 3          FINALIZADA           A-539/CENIPA/2018
# 4          FINALIZADA                         NaN
# 5                 NaN                         NaN
# 6          FINALIZADA                         NaN
# 7          FINALIZADA          IG-028/CENIPA/2011
# 8          FINALIZADA           I-004/CENIPA/2011
# 9                 NaN                         NaN
#
#   divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 0                            NÃO                       NaN
# 1                             20                        20
# 2                            NÃO                       NaN
# 3                            SIM                2019-10-28
# 4                            NÃO                       NaN
# 5                            NÃO                       NaN
# 6                            NÃO                       NaN
# 7                            SIM                2011-07-21
# 8                            SIM                2011-06-30
# 9                            NÃO                       NaN
#
#   total_recomendacoes  total_aeronaves_envolvidas  ocorrencia_saida_pista
# 0                   0                           1                     NÃO
# 1                  20                          20                      20
# 2                   0                           1                     NÃO
# 3                   0                           1                     NÃO
# 4                   0                           1                     NÃO
# 5                   0                           1                     NÃO
# 6                   0                           1                     SIM
# 7                   3                           1                     NÃO
# 8                   2                           1                     NÃO
# 9                   0                           1                     NÃO
#
# [10 rows x 21 columns]

# %%
dataframe['ocorrencia_uf_bkp'] = dataframe.ocorrencia_uf

# %%
dataframe.head(10)
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               40211               40211               40211
# 1                  20                  20                  20
# 2               40351               40351               40351
# 3               39527               39527               39527
# 4               40324               40324               40324
# 5               39807               39807               39807
# 6               40215               40215               40215
# 7               39707               39707               39707
# 8               39156               39156               39156
# 9               39711               39711               39711
#
#    codigo_ocorrencia4 ocorrencia_classificacao  ocorrencia_latitude  \
# 0               40211                INCIDENTE                   10
# 1                  20                       20                   10
# 2               40351                INCIDENTE                   10
# 3               39527                 ACIDENTE                   10
# 4               40324                INCIDENTE                   10
# 5               39807                INCIDENTE                   10
# 6               40215                INCIDENTE                   10
# 7               39707          INCIDENTE GRAVE                   10
# 8               39156          INCIDENTE GRAVE                   10
# 9               39711          INCIDENTE GRAVE                   10
#
#   ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                  ***      RIO DE JANEIRO            RJ          BRASIL  ...
# 1                   20                  20            20              20  ...
# 2                  NaN      RIO DE JANEIRO            RJ          BRASIL  ...
# 3       -55.9930555556  LUCAS DO RIO VERDE            MT          BRASIL  ...
# 4                  NaN             PELOTAS            RS          BRASIL  ...
# 5                  ***            SALVADOR            BA          BRASIL  ...
# 6                  ***               COARI            AM          BRASIL  ...
# 7       -64.3805555556            CANUTAMA            AM          BRASIL  ...
# 8       -59.3541666667            CASCAVEL            PR          BRASIL  ...
# 9                  ***       PARÁ DE MINAS            MG          BRASIL  ...
#
#   ocorrencia_hora investigacao_aeronave_liberada investigacao_status  \
# 0        12:00:00                            SIM          FINALIZADA
# 1              20                             20                  20
# 2        03:00:00                            SIM          FINALIZADA
# 3        17:30:00                            SIM          FINALIZADA
# 4        19:25:00                            SIM          FINALIZADA
# 5        17:53:00                            ***                 NaN
# 6        18:40:00                            SIM          FINALIZADA
# 7        12:30:00                            SIM          FINALIZADA
# 8        23:15:00                            SIM          FINALIZADA
# 9        20:00:00                            ***                 NaN
#
#   divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 0                         ***                            NÃO
# 1                          20                             20
# 2                         NaN                            NÃO
# 3           A-539/CENIPA/2018                            SIM
# 4                         NaN                            NÃO
# 5                         NaN                            NÃO
# 6                         NaN                            NÃO
# 7          IG-028/CENIPA/2011                            SIM
# 8           I-004/CENIPA/2011                            SIM
# 9                         NaN                            NÃO
#
#   divulgacao_dia_publicacao total_recomendacoes total_aeronaves_envolvidas  \
# 0                       NaN                   0                          1
# 1                        20                  20                         20
# 2                       NaN                   0                          1
# 3                2019-10-28                   0                          1
# 4                       NaN                   0                          1
# 5                       NaN                   0                          1
# 6                       NaN                   0                          1
# 7                2011-07-21                   3                          1
# 8                2011-06-30                   2                          1
# 9                       NaN                   0                          1
#
#    ocorrencia_saida_pista  ocorrencia_uf_bkp
# 0                     NÃO                 RJ
# 1                      20                 20
# 2                     NÃO                 RJ
# 3                     NÃO                 MT
# 4                     NÃO                 RS
# 5                     NÃO                 BA
# 6                     SIM                 AM
# 7                     NÃO                 AM
# 8                     NÃO                 PR
# 9                     NÃO                 MG
#
# [10 rows x 22 columns]

# %%
dataframe.loc[dataframe.ocorrencia_uf == 'SP',['ocorrencia_classificacao']] = 'Não há INCIDENTE'

# %%
dataframe.loc[dataframe.ocorrencia_uf == 'SP',['ocorrencia_classificacao']]
# Out:
#      ocorrencia_classificacao
# 11           Não há INCIDENTE
# 16           Não há INCIDENTE
# 18           Não há INCIDENTE
# 26           Não há INCIDENTE
# 27           Não há INCIDENTE
# ...                       ...
# 6084         Não há INCIDENTE
# 6085         Não há INCIDENTE
# 6104         Não há INCIDENTE
# 6108         Não há INCIDENTE
# 6113         Não há INCIDENTE
#
# [1464 rows x 1 columns]

# %%
dataframe.head(10)
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               40211               40211               40211
# 1                  20                  20                  20
# 2               40351               40351               40351
# 3               39527               39527               39527
# 4               40324               40324               40324
# 5               39807               39807               39807
# 6               40215               40215               40215
# 7               39707               39707               39707
# 8               39156               39156               39156
# 9               39711               39711               39711
#
#    codigo_ocorrencia4 ocorrencia_classificacao  ocorrencia_latitude  \
# 0               40211                INCIDENTE                   10
# 1                  20                       20                   10
# 2               40351                INCIDENTE                   10
# 3               39527                 ACIDENTE                   10
# 4               40324                INCIDENTE                   10
# 5               39807                INCIDENTE                   10
# 6               40215                INCIDENTE                   10
# 7               39707          INCIDENTE GRAVE                   10
# 8               39156          INCIDENTE GRAVE                   10
# 9               39711          INCIDENTE GRAVE                   10
#
#   ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                  ***      RIO DE JANEIRO            RJ          BRASIL  ...
# 1                   20                  20            20              20  ...
# 2                  NaN      RIO DE JANEIRO            RJ          BRASIL  ...
# 3       -55.9930555556  LUCAS DO RIO VERDE            MT          BRASIL  ...
# 4                  NaN             PELOTAS            RS          BRASIL  ...
# 5                  ***            SALVADOR            BA          BRASIL  ...
# 6                  ***               COARI            AM          BRASIL  ...
# 7       -64.3805555556            CANUTAMA            AM          BRASIL  ...
# 8       -59.3541666667            CASCAVEL            PR          BRASIL  ...
# 9                  ***       PARÁ DE MINAS            MG          BRASIL  ...
#
#   ocorrencia_hora investigacao_aeronave_liberada investigacao_status  \
# 0        12:00:00                            SIM          FINALIZADA
# 1              20                             20                  20
# 2        03:00:00                            SIM          FINALIZADA
# 3        17:30:00                            SIM          FINALIZADA
# 4        19:25:00                            SIM          FINALIZADA
# 5        17:53:00                            ***                 NaN
# 6        18:40:00                            SIM          FINALIZADA
# 7        12:30:00                            SIM          FINALIZADA
# 8        23:15:00                            SIM          FINALIZADA
# 9        20:00:00                            ***                 NaN
#
#   divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 0                         ***                            NÃO
# 1                          20                             20
# 2                         NaN                            NÃO
# 3           A-539/CENIPA/2018                            SIM
# 4                         NaN                            NÃO
# 5                         NaN                            NÃO
# 6                         NaN                            NÃO
# 7          IG-028/CENIPA/2011                            SIM
# 8           I-004/CENIPA/2011                            SIM
# 9                         NaN                            NÃO
#
#   divulgacao_dia_publicacao total_recomendacoes total_aeronaves_envolvidas  \
# 0                       NaN                   0                          1
# 1                        20                  20                         20
# 2                       NaN                   0                          1
# 3                2019-10-28                   0                          1
# 4                       NaN                   0                          1
# 5                       NaN                   0                          1
# 6                       NaN                   0                          1
# 7                2011-07-21                   3                          1
# 8                2011-06-30                   2                          1
# 9                       NaN                   0                          1
#
#    ocorrencia_saida_pista  ocorrencia_uf_bkp
# 0                     NÃO                 RJ
# 1                      20                 20
# 2                     NÃO                 RJ
# 3                     NÃO                 MT
# 4                     NÃO                 RS
# 5                     NÃO                 BA
# 6                     SIM                 AM
# 7                     NÃO                 AM
# 8                     NÃO                 PR
# 9                     NÃO                 MG
#
# [10 rows x 22 columns]

# %%
dataframe.loc[dataframe.ocorrencia_uf == 'SP']
# Out:
#       codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 11                 40069               40069               40069
# 16                 39809               39809               39809
# 18                 39828               39828               39828
# 26                 39847               39847               39847
# 27                 39768               39768               39768
# ...                  ...                 ...                 ...
# 6084               80234               80234               80234
# 6085               80208               80208               80208
# 6104               80238               80238               80238
# 6108               80244               80244               80244
# 6113               80259               80259               80259
#
#       codigo_ocorrencia4 ocorrencia_classificacao  ocorrencia_latitude  \
# 11                 40069         Não há INCIDENTE                   10
# 16                 39809         Não há INCIDENTE                   10
# 18                 39828         Não há INCIDENTE                   10
# 26                 39847         Não há INCIDENTE                   10
# 27                 39768         Não há INCIDENTE                   10
# ...                  ...                      ...                  ...
# 6084               80234         Não há INCIDENTE                   10
# 6085               80208         Não há INCIDENTE                   10
# 6104               80238         Não há INCIDENTE                   10
# 6108               80244         Não há INCIDENTE                   10
# 6113               80259         Não há INCIDENTE                   10
#
#      ocorrencia_longitude  ocorrencia_cidade ocorrencia_uf ocorrencia_pais  \
# 11         -46.6341666667          SÃO PAULO            SP          BRASIL
# 16                    NaN          SÃO PAULO            SP          BRASIL
# 18                    ***             SANTOS            SP          BRASIL
# 26                    NaN           SOROCABA            SP          BRASIL
# 27                    NaN           CAMPINAS            SP          BRASIL
# ...                   ...                ...           ...             ...
# 6084           -46.656389          SÃO PAULO            SP          BRASIL
# 6085           -46.633889          SÃO PAULO            SP          BRASIL
# 6104           -50.002500        VOTUPORANGA            SP          BRASIL
# 6108          -46.537076°  BRAGANÇA PAULISTA            SP          BRASIL
# 6113      -47.13444444444           CAMPINAS            SP          BRASIL
#
#       ... ocorrencia_hora investigacao_aeronave_liberada investigacao_status  \
# 11    ...        14:50:00                            SIM          FINALIZADA
# 16    ...        15:00:00                            ***                 NaN
# 18    ...        17:45:00                            ***                 NaN
# 26    ...        13:10:00                            ***                 NaN
# 27    ...        20:45:00                            ***                 NaN
# ...   ...             ...                            ...                 ...
# 6084  ...        13:20:00                            SIM          FINALIZADA
# 6085  ...        19:45:00                            SIM          FINALIZADA
# 6104  ...        19:09:00                            SIM               ATIVA
# 6108  ...        15:20:00                            SIM          FINALIZADA
# 6113  ...        12:45:00                            SIM          FINALIZADA
#
#      divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 11             A-121/CENIPA/2012                            SIM
# 16                           NaN                            NÃO
# 18                           NaN                            NÃO
# 26                           NaN                            NÃO
# 27                           NaN                            NÃO
# ...                          ...                            ...
# 6084                         ***                            NÃO
# 6085                         ***                            NÃO
# 6104                         ***                            NÃO
# 6108                         ***                            NÃO
# 6113                         ***                            NÃO
#
#      divulgacao_dia_publicacao total_recomendacoes total_aeronaves_envolvidas  \
# 11                  2012-11-19                   8                          1
# 16                         NaN                   0                          1
# 18                         NaN                   0                          1
# 26                         NaN                   0                          1
# 27                         NaN                   0                          1
# ...                        ...                 ...                        ...
# 6084                       NaN                   0                          1
# 6085                       NaN                   0                          1
# 6104                       NaN                   0                          1
# 6108                       NaN                   0                          1
# 6113                       NaN                   0                          1
#
#       ocorrencia_saida_pista  ocorrencia_uf_bkp
# 11                       NÃO                 SP
# 16                       NÃO                 SP
# 18                       NÃO                 SP
# 26                       NÃO                 SP
# 27                       NÃO                 SP
# ...                      ...                ...
# 6084                     NÃO                 SP
# 6085                     NÃO                 SP
# 6104                     NÃO                 SP
# 6108                     NÃO                 SP
# 6113                     NÃO                 SP
#
# [1464 rows x 22 columns]

# %%
dataframe
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                 40211               40211               40211
# 1                 40349               40349               40349
# 2                 40351               40351               40351
# 3                 39527               39527               39527
# 4                 40324               40324               40324
# ...                 ...                 ...                 ...
# 6109              80245               80245               80245
# 6110              80247               80247               80247
# 6111              80251               80251               80251
# 6112              80257               80257               80257
# 6113              80259               80259               80259
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                  40211               40211                INCIDENTE
# 1                  40349               40349                INCIDENTE
# 2                  40351               40351                INCIDENTE
# 3                  39527               39527                 ACIDENTE
# 4                  40324               40324                INCIDENTE
# ...                  ...                 ...                      ...
# 6109               80245               80245                INCIDENTE
# 6110               80247               80247                INCIDENTE
# 6111               80251               80251                INCIDENTE
# 6112               80257               80257                 ACIDENTE
# 6113               80259               80259                INCIDENTE
#
#      ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade  \
# 0                    ***                  ***      RIO DE JANEIRO
# 1                    NaN                  NaN               BELÉM
# 2                    NaN                  NaN      RIO DE JANEIRO
# 3         -13.1066666667       -55.9930555556  LUCAS DO RIO VERDE
# 4                    NaN                  NaN             PELOTAS
# ...                  ...                  ...                 ...
# 6109            -8.12638            -34.92277              RECIFE
# 6110     -8.713611111111      -63.90277777777         PORTO VELHO
# 6111     -1.384722222222      -48.47888888888               BELÉM
# 6112          -15.430833           -54.699722          DOM AQUINO
# 6113     -23.00694444444      -47.13444444444            CAMPINAS
#
#      ocorrencia_uf  ... ocorrencia_dia ocorrencia_hora  \
# 0               RJ  ...     2010-01-03        12:00:00
# 1               PA  ...     2010-01-03        11:05:00
# 2               RJ  ...     2010-01-03        03:00:00
# 3               MT  ...     2010-01-04        17:30:00
# 4               RS  ...     2010-01-05        19:25:00
# ...            ...  ...            ...             ...
# 6109            PE  ...     2021-08-15        15:05:00
# 6110            RO  ...     2021-08-16        02:30:00
# 6111            PA  ...     2021-08-17        15:45:00
# 6112            MT  ...     2021-08-18        16:00:00
# 6113            SP  ...     2021-08-18        12:45:00
#
#      investigacao_aeronave_liberada investigacao_status  \
# 0                               SIM          FINALIZADA
# 1                               SIM          FINALIZADA
# 2                               SIM          FINALIZADA
# 3                               SIM          FINALIZADA
# 4                               SIM          FINALIZADA
# ...                             ...                 ...
# 6109                            SIM          FINALIZADA
# 6110                            SIM          FINALIZADA
# 6111                            SIM          FINALIZADA
# 6112                            SIM          FINALIZADA
# 6113                            SIM          FINALIZADA
#
#      divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 0                            ***                            NÃO
# 1                            NaN                            NÃO
# 2                            NaN                            NÃO
# 3              A-539/CENIPA/2018                            SIM
# 4                            NaN                            NÃO
# ...                          ...                            ...
# 6109                         ***                            NÃO
# 6110                         ***                            NÃO
# 6111                         ***                            NÃO
# 6112                         ***                            NÃO
# 6113                         ***                            NÃO
#
#      divulgacao_dia_publicacao total_recomendacoes total_aeronaves_envolvidas  \
# 0                          NaN                   0                          1
# 1                          NaN                   0                          1
# 2                          NaN                   0                          1
# 3                   2019-10-28                   0                          1
# 4                          NaN                   0                          1
# ...                        ...                 ...                        ...
# 6109                       NaN                   0                          1
# 6110                       NaN                   0                          1
# 6111                       NaN                   0                          1
# 6112                       NaN                   0                          1
# 6113                       NaN                   0                          1
#
#       ocorrencia_saida_pista
# 0                        NÃO
# 1                        NÃO
# 2                        NÃO
# 3                        NÃO
# 4                        NÃO
# ...                      ...
# 6109                     NÃO
# 6110                     NÃO
# 6111                     NÃO
# 6112                     NÃO
# 6113                     NÃO
#
# [6114 rows x 22 columns]

# %%
# ocorrencia_uf
# **
# ocorrencia_aerodromo
# ###!
# ####
# ****
# *****
# ocorrencia_hora
# NULL

# %%
dataframe.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
# 4               40324               40324                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 0                 ***                  ***      RIO DE JANEIRO            RJ
# 1                 NaN                  NaN               BELÉM            PA
# 2                 NaN                  NaN      RIO DE JANEIRO            RJ
# 3      -13.1066666667       -55.9930555556  LUCAS DO RIO VERDE            MT
# 4                 NaN                  NaN             PELOTAS            RS
#
#    ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 0  ...     2010-01-03        12:00:00                            SIM
# 1  ...     2010-01-03        11:05:00                            SIM
# 2  ...     2010-01-03        03:00:00                            SIM
# 3  ...     2010-01-04        17:30:00                            SIM
# 4  ...     2010-01-05        19:25:00                            SIM
#
#   investigacao_status divulgacao_relatorio_numero  \
# 0          FINALIZADA                         ***
# 1          FINALIZADA                         NaN
# 2          FINALIZADA                         NaN
# 3          FINALIZADA           A-539/CENIPA/2018
# 4          FINALIZADA                         NaN
#
#   divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 0                            NÃO                       NaN
# 1                            NÃO                       NaN
# 2                            NÃO                       NaN
# 3                            SIM                2019-10-28
# 4                            NÃO                       NaN
#
#   total_recomendacoes total_aeronaves_envolvidas  ocorrencia_saida_pista
# 0                   0                          1                     NÃO
# 1                   0                          1                     NÃO
# 2                   0                          1                     NÃO
# 3                   0                          1                     NÃO
# 4                   0                          1                     NÃO
#
# [5 rows x 22 columns]

# %%
dataframe.loc[dataframe.ocorrencia_aerodromo == '****', ['ocorrencia_aerodromo']] = pd.NA

# %%
dataframe
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                 40211               40211               40211
# 1                 40349               40349               40349
# 2                 40351               40351               40351
# 3                 39527               39527               39527
# 4                 40324               40324               40324
# ...                 ...                 ...                 ...
# 6109              80245               80245               80245
# 6110              80247               80247               80247
# 6111              80251               80251               80251
# 6112              80257               80257               80257
# 6113              80259               80259               80259
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                  40211               40211                INCIDENTE
# 1                  40349               40349                INCIDENTE
# 2                  40351               40351                INCIDENTE
# 3                  39527               39527                 ACIDENTE
# 4                  40324               40324                INCIDENTE
# ...                  ...                 ...                      ...
# 6109               80245               80245                INCIDENTE
# 6110               80247               80247                INCIDENTE
# 6111               80251               80251                INCIDENTE
# 6112               80257               80257                 ACIDENTE
# 6113               80259               80259                INCIDENTE
#
#      ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade  \
# 0                    ***                  ***      RIO DE JANEIRO
# 1                    NaN                  NaN               BELÉM
# 2                    NaN                  NaN      RIO DE JANEIRO
# 3         -13.1066666667       -55.9930555556  LUCAS DO RIO VERDE
# 4                    NaN                  NaN             PELOTAS
# ...                  ...                  ...                 ...
# 6109            -8.12638            -34.92277              RECIFE
# 6110     -8.713611111111      -63.90277777777         PORTO VELHO
# 6111     -1.384722222222      -48.47888888888               BELÉM
# 6112          -15.430833           -54.699722          DOM AQUINO
# 6113     -23.00694444444      -47.13444444444            CAMPINAS
#
#      ocorrencia_uf  ... ocorrencia_dia ocorrencia_hora  \
# 0               RJ  ...     2010-01-03        12:00:00
# 1               PA  ...     2010-01-03        11:05:00
# 2               RJ  ...     2010-01-03        03:00:00
# 3               MT  ...     2010-01-04        17:30:00
# 4               RS  ...     2010-01-05        19:25:00
# ...            ...  ...            ...             ...
# 6109            PE  ...     2021-08-15        15:05:00
# 6110            RO  ...     2021-08-16        02:30:00
# 6111            PA  ...     2021-08-17        15:45:00
# 6112            MT  ...     2021-08-18        16:00:00
# 6113            SP  ...     2021-08-18        12:45:00
#
#      investigacao_aeronave_liberada investigacao_status  \
# 0                               SIM          FINALIZADA
# 1                               SIM          FINALIZADA
# 2                               SIM          FINALIZADA
# 3                               SIM          FINALIZADA
# 4                               SIM          FINALIZADA
# ...                             ...                 ...
# 6109                            SIM          FINALIZADA
# 6110                            SIM          FINALIZADA
# 6111                            SIM          FINALIZADA
# 6112                            SIM          FINALIZADA
# 6113                            SIM          FINALIZADA
#
#      divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 0                            ***                            NÃO
# 1                            NaN                            NÃO
# 2                            NaN                            NÃO
# 3              A-539/CENIPA/2018                            SIM
# 4                            NaN                            NÃO
# ...                          ...                            ...
# 6109                         ***                            NÃO
# 6110                         ***                            NÃO
# 6111                         ***                            NÃO
# 6112                         ***                            NÃO
# 6113                         ***                            NÃO
#
#      divulgacao_dia_publicacao total_recomendacoes total_aeronaves_envolvidas  \
# 0                          NaN                   0                          1
# 1                          NaN                   0                          1
# 2                          NaN                   0                          1
# 3                   2019-10-28                   0                          1
# 4                          NaN                   0                          1
# ...                        ...                 ...                        ...
# 6109                       NaN                   0                          1
# 6110                       NaN                   0                          1
# 6111                       NaN                   0                          1
# 6112                       NaN                   0                          1
# 6113                       NaN                   0                          1
#
#       ocorrencia_saida_pista
# 0                        NÃO
# 1                        NÃO
# 2                        NÃO
# 3                        NÃO
# 4                        NÃO
# ...                      ...
# 6109                     NÃO
# 6110                     NÃO
# 6111                     NÃO
# 6112                     NÃO
# 6113                     NÃO
#
# [6114 rows x 22 columns]

# %%
dataframe.loc[:, ['codigo_ocorrencia','ocorrencia_aerodromo']]
# Out:
#       codigo_ocorrencia ocorrencia_aerodromo
# 0                 40211                 <NA>
# 1                 40349                 SBBE
# 2                 40351                 SBRJ
# 3                 39527                 <NA>
# 4                 40324                 SBPK
# ...                 ...                  ...
# 6109              80245                 SBRF
# 6110              80247                 SBPV
# 6111              80251                 SBBE
# 6112              80257                 <NA>
# 6113              80259                 SBKP
#
# [6114 rows x 2 columns]

# %%
dataframe.replace(['**','###!','####','****', '*****', 'NULL'], pd.NA, inplace=True)

# %%
dataframe.isna().sum()
# Out:
# codigo_ocorrencia                    0
# codigo_ocorrencia1                   0
# codigo_ocorrencia2                   0
# codigo_ocorrencia3                   0
# codigo_ocorrencia4                   0
# ocorrencia_classificacao             0
# ocorrencia_latitude                  4
# ocorrencia_longitude                 5
# ocorrencia_cidade                    0
# ocorrencia_uf                        0
# ocorrencia_pais                      0
# ocorrencia_aerodromo              2456
# ocorrencia_dia                       0
# ocorrencia_hora                      0
# investigacao_aeronave_liberada       0
# investigacao_status                  0
# divulgacao_relatorio_numero          7
# divulgacao_relatorio_publicado       0
# divulgacao_dia_publicacao            0
# total_recomendacoes                  0
# total_aeronaves_envolvidas           0
# ocorrencia_saida_pista               0
# dtype: int64

# %%
dataframe.isnull().sum()
# Out:
# codigo_ocorrencia                    0
# codigo_ocorrencia1                   0
# codigo_ocorrencia2                   0
# codigo_ocorrencia3                   0
# codigo_ocorrencia4                   0
# ocorrencia_classificacao             0
# ocorrencia_latitude                  4
# ocorrencia_longitude                 5
# ocorrencia_cidade                    0
# ocorrencia_uf                        0
# ocorrencia_pais                      0
# ocorrencia_aerodromo              2456
# ocorrencia_dia                       0
# ocorrencia_hora                      0
# investigacao_aeronave_liberada       0
# investigacao_status                  0
# divulgacao_relatorio_numero          7
# divulgacao_relatorio_publicado       0
# divulgacao_dia_publicacao            0
# total_recomendacoes                  0
# total_aeronaves_envolvidas           0
# ocorrencia_saida_pista               0
# dtype: int64

# %%
dataframe.loc[40211]
# Out:
# codigo_ocorrencia1                              40211
# codigo_ocorrencia2                              40211
# codigo_ocorrencia3                              40211
# codigo_ocorrencia4                              40211
# ocorrencia_classificacao                    INCIDENTE
# ocorrencia_latitude                               ***
# ocorrencia_longitude                              ***
# ocorrencia_cidade                      RIO DE JANEIRO
# ocorrencia_uf                                      RJ
# ocorrencia_pais                                BRASIL
# ocorrencia_aerodromo                                0
# ocorrencia_dia                    2010-01-03 00:00:00
# ocorrencia_hora                              12:00:00
# investigacao_aeronave_liberada                    SIM
# investigacao_status                        FINALIZADA
# divulgacao_relatorio_numero                       ***
# divulgacao_relatorio_publicado                    NÃO
# divulgacao_dia_publicacao                           0
# total_recomendacoes                                 0
# total_aeronaves_envolvidas                          1
# ocorrencia_saida_pista                            NÃO
# Name: 40211, dtype: object

# %%
dataframe.loc[:, ['codigo_ocorrencia','ocorrencia_aerodromo']]
# Out:
#       codigo_ocorrencia ocorrencia_aerodromo
# 0                 40211                 ****
# 1                 40349                 SBBE
# 2                 40351                 SBRJ
# 3                 39527                 ****
# 4                 40324                 SBPK
# ...                 ...                  ...
# 6109              80245                 SBRF
# 6110              80247                 SBPV
# 6111              80251                 SBBE
# 6112              80257                 ****
# 6113              80259                 SBKP
#
# [6114 rows x 2 columns]

# %%
dataframe.isna().sum()
# Out:
# codigo_ocorrencia                    0
# codigo_ocorrencia1                   0
# codigo_ocorrencia2                   0
# codigo_ocorrencia3                   0
# codigo_ocorrencia4                   0
# ocorrencia_classificacao             0
# ocorrencia_latitude                  4
# ocorrencia_longitude                 5
# ocorrencia_cidade                    0
# ocorrencia_uf                        0
# ocorrencia_pais                      0
# ocorrencia_aerodromo              2456
# ocorrencia_dia                       0
# ocorrencia_hora                      0
# investigacao_aeronave_liberada       0
# investigacao_status                  0
# divulgacao_relatorio_numero          7
# divulgacao_relatorio_publicado       0
# divulgacao_dia_publicacao            0
# total_recomendacoes                  0
# total_aeronaves_envolvidas           0
# ocorrencia_saida_pista               0
# dtype: int64

# %%
dataframe.fillna(0, inplace=True)

# %%
dataframe.loc[:, ['codigo_ocorrencia','ocorrencia_aerodromo']]
# Out:
#       codigo_ocorrencia ocorrencia_aerodromo
# 0                 40211                    0
# 1                 40349                 SBBE
# 2                 40351                 SBRJ
# 3                 39527                    0
# 4                 40324                 SBPK
# ...                 ...                  ...
# 6109              80245                 SBRF
# 6110              80247                 SBPV
# 6111              80251                 SBBE
# 6112              80257                    0
# 6113              80259                 SBKP
#
# [6114 rows x 2 columns]

# %%
dataframe.fillna(value{'total_recomendacoes':10}, inplace=True)

# %%
dataframe.isnull().sum()

# %%
dataframe['total_recomendacoes_bkp'] = dataframe.total_recomendacoes

# %%
dataframe.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
# 4               40324               40324                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 0                 ***                  ***      RIO DE JANEIRO            RJ
# 1                 NaN                  NaN               BELÉM            PA
# 2                 NaN                  NaN      RIO DE JANEIRO            RJ
# 3      -13.1066666667       -55.9930555556  LUCAS DO RIO VERDE            MT
# 4                 NaN                  NaN             PELOTAS            RS
#
#    ... ocorrencia_hora investigacao_aeronave_liberada investigacao_status  \
# 0  ...        12:00:00                            SIM          FINALIZADA
# 1  ...        11:05:00                            SIM          FINALIZADA
# 2  ...        03:00:00                            SIM          FINALIZADA
# 3  ...        17:30:00                            SIM          FINALIZADA
# 4  ...        19:25:00                            SIM          FINALIZADA
#
#   divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 0                         ***                            NÃO
# 1                         NaN                            NÃO
# 2                         NaN                            NÃO
# 3           A-539/CENIPA/2018                            SIM
# 4                         NaN                            NÃO
#
#   divulgacao_dia_publicacao total_recomendacoes total_aeronaves_envolvidas  \
# 0                       NaN                   0                          1
# 1                       NaN                   0                          1
# 2                       NaN                   0                          1
# 3                2019-10-28                   0                          1
# 4                       NaN                   0                          1
#
#   ocorrencia_saida_pista  total_recomendacoes_bkp
# 0                    NÃO                        0
# 1                    NÃO                        0
# 2                    NÃO                        0
# 3                    NÃO                        0
# 4                    NÃO                        0
#
# [5 rows x 23 columns]

# %%
dataframe.drop(['total_recomendacoes_bkp'], axis=1, inplace=True)

# %%
dataframe.dropna(subset=['ocorrencia_uf'])

# %%
dataframe.dop_duplicate(inplace=True)

# %%
dataframe

# %% [markdown]
# # Trabalho professor Manuel  Estatística Aplica a negócios
# ## Grupo:
# - Wendy Cataldo – 2013201439
# - Willian da Silva Dantas – 2014102370

# %%
#Importa as bibliotecas necessárias
import pandas as pd
import openpyxl
import matplotlib.pyplot as plt
import scipy.stats
import numpy as np

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
#Carrega o dataframe de dados
df = pd.read_excel('tx_bruta_mortalidade_RJ.xlsx')
df=df.set_index("Município")
df.head()
# Out:
#                         2000      2001      2002      2003      2004  \
# Município
# Angra dos Reis      4.688409  5.494377  5.456208  4.961169  4.921486
# Aperibé             6.461051  8.035925  7.586207  5.600358  6.336720
# Araruama            6.645656  6.816687  6.897080  6.695695  7.772473
# Areal               5.726698  5.336697  6.972968  5.740636  7.142195
# Armação dos Búzios  5.959732  4.814271  4.288330  5.061427  5.418741
#
#                         2005      2006      2007      2008      2009  ...  \
# Município                                                             ...
# Angra dos Reis      5.460884  4.899250  4.804475  5.050381  4.975628  ...
# Aperibé             7.576566  5.740528  6.029637  7.105685  7.056056  ...
# Araruama            6.699500  7.303447  7.616204  7.919771  7.315322  ...
# Areal               5.397493  7.674944  6.954351  7.483712  6.346171  ...
# Armação dos Búzios  5.500317  5.665838  5.509859  5.552175  5.771422  ...
#
#                         2012      2013      2014      2015      2016  \
# Município
# Angra dos Reis      4.969138  5.379666  5.331302  5.401113  5.227894
# Aperibé             6.727086  8.847111  8.632440  7.881068  8.042422
# Araruama            7.732373  8.296612  8.271976  8.531530  8.445358
# Areal               6.161898  6.779377  7.964161  7.316672  7.092199
# Armação dos Búzios  6.031692  6.537910  7.050069  6.863089  7.820565
#
#                         2017      2018      2019      2020       2021
# Município
# Angra dos Reis      5.311937  5.768262  5.471453  6.573482   6.380286
# Aperibé             7.853403  8.525663  5.442640  8.318629   9.410974
# Araruama            8.659694  8.034407  8.421450  9.233542  10.998339
# Areal               7.843454  8.098789  8.431435  8.603678  10.498066
# Armação dos Búzios  7.272393  7.490975  7.794508  8.556429   9.571598
#
# [5 rows x 22 columns]

# %% [markdown]
# # quantidade de valores, media, desvio, alguns quartis

# %%
df.describe()
# Out:
#             2000       2001       2002       2003       2004       2005  \
# count  92.000000  92.000000  92.000000  92.000000  92.000000  92.000000
# mean    6.789792   6.799110   6.870903   6.906196   6.874197   6.753657
# std     1.294308   1.114746   1.120001   1.241078   1.185604   1.193647
# min     0.000000   3.771308   4.288330   4.223043   4.469505   3.298611
# 25%     6.182026   5.956269   6.115280   6.023312   6.280521   5.916391
# 50%     6.906514   6.825371   6.978982   6.954993   6.875969   6.694074
# 75%     7.598632   7.727270   7.472015   7.808452   7.660738   7.478515
# max     9.355380   8.957452   9.512406  11.130639  11.242489  10.777521
#
#             2006       2007       2008       2009  ...       2012       2013  \
# count  92.000000  92.000000  92.000000  92.000000  ...  92.000000  92.000000
# mean    6.808354   6.929976   7.138702   7.075074  ...   7.339212   7.501050
# std     1.167516   1.083012   1.291333   1.141171  ...   1.206427   1.242762
# min     4.080854   4.696548   4.537359   4.645316  ...   4.857085   4.274388
# 25%     5.839122   6.020694   6.429402   6.497818  ...   6.591643   6.782929
# 50%     6.923224   7.021150   7.181707   7.031063  ...   7.298473   7.558920
# 75%     7.671703   7.651106   7.779017   7.732257  ...   8.096956   8.217558
# max     9.874048  10.092097  13.016412  11.804384  ...  10.514665  12.853470
#
#             2014       2015       2016       2017       2018       2019  \
# count  92.000000  92.000000  92.000000  92.000000  92.000000  92.000000
# mean    7.553722   7.586789   7.944917   7.870453   7.944653   7.964627
# std     1.139535   1.130521   1.238063   1.086134   1.083365   1.409543
# min     5.152630   5.210801   4.781101   5.084853   5.174886   4.059108
# 25%     6.846413   6.835102   7.183622   7.265909   7.358105   7.133513
# 50%     7.540442   7.452483   8.090344   7.848429   8.066598   7.995409
# 75%     8.198289   8.247430   8.801621   8.586468   8.563498   8.929147
# max    11.394466  11.274777  10.727108  10.847808  11.661285  11.692726
#
#             2020       2021
# count  92.000000  92.000000
# mean    9.342295  10.134274
# std     1.531527   1.832044
# min     5.957742   5.132361
# 25%     8.372891   9.048225
# 50%     9.322585  10.090291
# 75%    10.207520  11.285963
# max    13.786514  14.564622
#
# [8 rows x 22 columns]

# %% [markdown]
# # Media de municipios

# %%
media_mun = df.mean(1)
media_mun
# Out:
# Município
# Angra dos Reis        5.299367
# Aperibé               7.363242
# Araruama              7.905830
# Areal                 7.194039
# Armação dos Búzios    6.363618
#                         ...
# Três Rios             8.312456
# Valença               8.512180
# Varre-Sai             5.961292
# Vassouras             8.986956
# Volta Redonda         7.577701
# Length: 92, dtype: float64

# %% [markdown]
# # Media por Ano

# %%
media_ano = df.mean()
print('Média por ano')
media_ano
# Out:
# Média por ano
# 2000     6.789792
# 2001     6.799110
# 2002     6.870903
# 2003     6.906196
# 2004     6.874197
# 2005     6.753657
# 2006     6.808354
# 2007     6.929976
# 2008     7.138702
# 2009     7.075074
# 2010     7.271664
# 2011     7.370295
# 2012     7.339212
# 2013     7.501050
# 2014     7.553722
# 2015     7.586789
# 2016     7.944917
# 2017     7.870453
# 2018     7.944653
# 2019     7.964627
# 2020     9.342295
# 2021    10.134274
# dtype: float64

# %% [markdown]
# # Função para retornar dados Estatisticos

# %%
def estatisticas(media, quartil=False):
    data=pd.DataFrame()
    if not quartil:
        data["Soma"]=media.sum(axis=1)
        data["Min"]=media.min(axis=1)
        data["Max"]=media.max(axis=1)
        data["Media"]=media.mean(axis=1)
        data["Mediana"]=media.median(axis=1)
        data["Coef_Var"]=media.std(axis=1,ddof=0)/media.median(axis=1)
        data["Vari_N"]=media.var(axis=1, ddof=0)
        data["Vari_N-1"]=media.var(axis=1)
        data["DesvPad_N"]=media.std(axis=1, ddof=0)
        data["DesvPad_N-1"]=media.std(axis=1)
        data["25%"] = media.quantile(axis=1, q=0.25)
        data["50%"] = media.quantile(axis=1, q=0.50)
        data["75%"] = media.quantile(axis=1, q=0.75)
        return data 
    else:
        data = pd.DataFrame(data=media, columns=["Mortalidade"])
        quartil=pd.DataFrame()
        q1 =  media.quantile(q=0.25)
        q2 = media.quantile(q=0.50)
        q3 = media.quantile(q=0.75)
        for x in data.index:
             if data.loc[x,"Mortalidade"] <= q1:
                    data.loc[x, "Quartil"] = 1
             elif data.loc[x,"Mortalidade"] > q1 and data.loc[x,"Mortalidade"] <=q2: 
                    data.loc[x, "Quartil"] = 2
             elif data.loc[x,"Mortalidade"] > q2 and data.loc[x,"Mortalidade"] <=q3:
                    data.loc[x, "Quartil"] = 3
             else:
                data.loc[x, "Quartil"] = 4
        data['Quartil'] = data['Quartil'].astype(int)
        data = data.set_index(["Quartil"])
        quartil["Soma"] = data.groupby('Quartil').sum()
        quartil["Min"]=data.groupby('Quartil').min()
        quartil["Max"]=data.groupby('Quartil').max()
        quartil["Media"]=data.groupby('Quartil').mean()
        quartil["Mediana"]=data.groupby('Quartil').median()
        quartil["Coef_Var"]=data.groupby('Quartil').std(ddof=0)/data.groupby('Quartil').median()
        quartil["Vari_N"]=data.groupby('Quartil').var(ddof=0)
        quartil["Vari_N-1"]=data.groupby('Quartil').var()
        quartil["DesvPad_N"]=data.groupby('Quartil').std(ddof=0)
        quartil["DesvPad_N-1"]=data.groupby('Quartil').std()
        quartil["25%"] = data.groupby('Quartil').quantile(q=0.25)
        quartil["50%"] = data.groupby('Quartil').quantile(q=0.50)
        quartil["75%"] = data.groupby('Quartil').quantile(q=0.75)
    return quartil

# %% [markdown]
# # Dados estatisticos por media ano

# %%
vetor_ano_media = pd.DataFrame(data=[media_ano], index=["Mortalidade"])
estatisticas(vetor_ano_media)
# Out:
#                    Soma       Min        Max     Media   Mediana  Coef_Var  \
# Mortalidade  164.769913  6.753657  10.134274  7.489541  7.305438  0.112999
#
#               Vari_N  Vari_N-1  DesvPad_N  DesvPad_N-1       25%       50%  \
# Mortalidade  0.68146  0.713911   0.825506     0.844932  6.882197  7.305438
#
#                   75%
# Mortalidade  7.799537

# %% [markdown]
# # Dados estatiticos por media de municipios

# %%
vetor_mun_media = pd.DataFrame(data=[media_mun], index=["Mortalidade"])
estatisticas(vetor_mun_media)
# Out:
#                    Soma       Min        Max     Media   Mediana  Coef_Var  \
# Mortalidade  689.037817  5.205127  10.670853  7.489541  7.546078  0.133626
#
#                Vari_N  Vari_N-1  DesvPad_N  DesvPad_N-1       25%       50%  \
# Mortalidade  1.016773  1.027947   1.008352     1.013877  6.863482  7.546078
#
#                   75%
# Mortalidade  8.093112

# %%
data = pd.DataFrame(data=media_ano, columns=["Mortalidade"])
quartil=pd.DataFrame()
q1 =  media_ano.quantile(q=0.25)
q2 = media_ano.quantile(q=0.50)
q3 = media_ano.quantile(q=0.75)
for x in data.index:
     if data.loc[x,"Mortalidade"] <= q1:
            data.loc[x, "Quartil"] = 1
     elif data.loc[x,"Mortalidade"] > q1 and data.loc[x,"Mortalidade"] <=q2: 
            data.loc[x, "Quartil"] = 2
     elif data.loc[x,"Mortalidade"] > q2 and data.loc[x,"Mortalidade"] <=q3:
            data.loc[x, "Quartil"] = 3
     else:
        data.loc[x, "Quartil"] = 4
data['Quartil'] = data['Quartil'].astype(int)
data = data.set_index(["Quartil"])
quartil["Soma"] = data.groupby('Quartil').sum()
quartil["Min"]=data.groupby('Quartil').min()
quartil["Max"]=data.groupby('Quartil').max()
quartil["Media"]=data.groupby('Quartil').mean()
quartil["Mediana"]=data.groupby('Quartil').median()
quartil["Coef_Var"]=data.groupby('Quartil').std(ddof=0)/data.groupby('Quartil').median()
quartil["Vari_N"]=data.groupby('Quartil').var(ddof=0)
quartil["Vari_N-1"]=data.groupby('Quartil').var()
quartil["DesvPad_N"]=data.groupby('Quartil').std(ddof=0)
quartil["DesvPad_N-1"]=data.groupby('Quartil').std()
quartil["25%"] = data.groupby('Quartil').quantile(q=0.25)
quartil["50%"] = data.groupby('Quartil').quantile(q=0.50)
quartil["75%"] = data.groupby('Quartil').quantile(q=0.75)

quartil
# Out:
#               Soma       Min        Max     Media   Mediana  Coef_Var  \
# Quartil
# 1        40.896014  6.753657   6.874197  6.816002  6.803732  0.006384
# 2        35.321612  6.906196   7.271664  7.064322  7.075074  0.019140
# 3        37.351067  7.339212   7.586789  7.470213  7.501050  0.013152
# 4        51.201220  7.870453  10.134274  8.533537  7.954772  0.110942
#
#            Vari_N  Vari_N-1  DesvPad_N  DesvPad_N-1       25%       50%  \
# Quartil
# 1        0.001886  0.002264   0.043433     0.047578  6.792122  6.803732
# 2        0.018338  0.022923   0.135419     0.151403  6.929976  7.075074
# 3        0.009732  0.012165   0.098650     0.110295  7.370295  7.501050
# 4        0.778841  0.934609   0.882519     0.966752  7.944719  7.954772
#
#               75%
# Quartil
# 1        6.855265
# 2        7.138702
# 3        7.553722
# 4        8.997878

# %% [markdown]
# # Mostra dados agrupados em quartis por media municipios

# %%
estatisticas(media_mun, quartil=True)
# Out:
#                Soma       Min        Max     Media   Mediana  Coef_Var  \
# Quartil
# 1        141.716149  5.205127   6.674194  6.161572  6.363618  0.069587
# 2        166.436344  6.926578   7.540910  7.236363  7.218169  0.027964
# 3        179.769606  7.551247   8.092415  7.816070  7.878777  0.021931
# 4        201.115717  8.095203  10.670853  8.744162  8.605685  0.062803
#
#            Vari_N  Vari_N-1  DesvPad_N  DesvPad_N-1       25%       50%  \
# Quartil
# 1        0.196094  0.205007   0.442825     0.452777  6.000862  6.363618
# 2        0.040744  0.042596   0.201851     0.206388  7.035896  7.218169
# 3        0.029856  0.031213   0.172789     0.176672  7.611777  7.878777
# 4        0.292104  0.305381   0.540466     0.552613  8.397480  8.605685
#
#               75%
# Quartil
# 1        6.480774
# 2        7.397312
# 3        7.947346
# 4        8.931980

# %% [markdown]
# # Mostra dados agrupados em quartis por media Ano

# %%
estatisticas(media_ano, quartil=True) # Mostra dados agrupados em quartis por media ano
# Out:
#               Soma       Min        Max     Media   Mediana  Coef_Var  \
# Quartil
# 1        40.896014  6.753657   6.874197  6.816002  6.803732  0.006384
# 2        35.321612  6.906196   7.271664  7.064322  7.075074  0.019140
# 3        37.351067  7.339212   7.586789  7.470213  7.501050  0.013152
# 4        51.201220  7.870453  10.134274  8.533537  7.954772  0.110942
#
#            Vari_N  Vari_N-1  DesvPad_N  DesvPad_N-1       25%       50%  \
# Quartil
# 1        0.001886  0.002264   0.043433     0.047578  6.792122  6.803732
# 2        0.018338  0.022923   0.135419     0.151403  6.929976  7.075074
# 3        0.009732  0.012165   0.098650     0.110295  7.370295  7.501050
# 4        0.778841  0.934609   0.882519     0.966752  7.944719  7.954772
#
#               75%
# Quartil
# 1        6.855265
# 2        7.138702
# 3        7.553722
# 4        8.997878

# %% [markdown]
# # Mostra dados estatiticos por municipios

# %%
municipio = df
estatisticas(municipio)  # Mostra dados estatiticos por municipios
# Out:
#                           Soma       Min        Max     Media   Mediana  \
# Município
# Angra dos Reis      116.586077  4.688409   6.573482  5.299367  5.269915
# Aperibé             161.991332  5.442640   9.410974  7.363242  7.577597
# Araruama            173.928253  6.645656  10.998339  7.905830  7.822091
# Areal               158.268869  5.336697  10.498066  7.194039  7.117197
# Armação dos Búzios  139.999593  4.288330   9.571598  6.363618  5.995712
# ...                        ...       ...        ...       ...       ...
# Três Rios           182.874032  7.156534  11.041854  8.312456  8.092885
# Valença             187.267958  7.591392  11.278929  8.512180  8.346460
# Varre-Sai           131.148422  4.376368   8.088601  5.961292  5.744384
# Vassouras           197.713033  7.118916  12.593372  8.986956  9.023224
# Volta Redonda       166.709427  6.418506  11.307065  7.577701  7.347364
#
#                     Coef_Var    Vari_N  Vari_N-1  DesvPad_N  DesvPad_N-1  \
# Município
# Angra dos Reis      0.086890  0.209676  0.219660   0.457904     0.468679
# Aperibé             0.142080  1.159128  1.214324   1.076628     1.101964
# Araruama            0.124090  0.942143  0.987007   0.970641     0.993482
# Areal               0.163691  1.357277  1.421909   1.165022     1.192438
# Armação dos Búzios  0.212490  1.623149  1.700441   1.274028     1.304010
# ...                      ...       ...       ...        ...          ...
# Três Rios           0.107543  0.757478  0.793548   0.870332     0.890813
# Valença             0.088879  0.550308  0.576513   0.741828     0.759285
# Varre-Sai           0.159542  0.839921  0.879917   0.916472     0.938039
# Vassouras           0.113823  1.054840  1.105070   1.027054     1.051223
# Volta Redonda       0.152727  1.259197  1.319159   1.122140     1.148547
#
#                          25%       50%       75%
# Município
# Angra dos Reis      4.970760  5.269915  5.459715
# Aperibé             6.527560  7.577597  8.040798
# Araruama            7.306416  7.822091  8.390241
# Areal               6.454472  7.117197  7.801327
# Armação dos Búzios  5.502703  5.995712  7.216812
# ...                      ...       ...       ...
# Três Rios           7.827453  8.092885  8.527390
# Valença             8.126281  8.346460  8.711566
# Varre-Sai           5.319648  5.744384  6.572905
# Vassouras           8.434270  9.023224  9.246862
# Volta Redonda       6.836253  7.347364  7.672345
#
# [92 rows x 13 columns]

# %% [markdown]
# # Mostra dados estatiticos por ano

# %%
ano = df.T
estatisticas(ano)  # Mostra dados estatiticos por ano
# Out:
#             Soma       Min        Max      Media    Mediana  Coef_Var  \
# 2000  624.660895  0.000000   9.355380   6.789792   6.906514  0.186383
# 2001  625.518122  3.771308   8.957452   6.799110   6.825371  0.162434
# 2002  632.123040  4.288330   9.512406   6.870903   6.978982  0.159607
# 2003  635.370039  4.223043  11.130639   6.906196   6.954993  0.177472
# 2004  632.426157  4.469505  11.242489   6.874197   6.875969  0.171488
# 2005  621.336456  3.298611  10.777521   6.753657   6.694074  0.177342
# 2006  626.368577  4.080854   9.874048   6.808354   6.923224  0.167719
# 2007  637.557751  4.696548  10.092097   6.929976   7.021150  0.153409
# 2008  656.760604  4.537359  13.016412   7.138702   7.181707  0.178829
# 2009  650.906813  4.645316  11.804384   7.075074   7.031063  0.161420
# 2010  668.993103  4.408516  10.450574   7.271664   7.358026  0.158846
# 2011  678.067118  4.692052  10.934025   7.370295   7.406652  0.164804
# 2012  675.207463  4.857085  10.514665   7.339212   7.298473  0.164398
# 2013  690.096578  4.274388  12.853470   7.501050   7.558920  0.163514
# 2014  694.942442  5.152630  11.394466   7.553722   7.540442  0.150300
# 2015  697.984554  5.210801  11.274777   7.586789   7.452483  0.150871
# 2016  730.932365  4.781101  10.727108   7.944917   8.090344  0.152196
# 2017  724.081710  5.084853  10.847808   7.870453   7.848429  0.137635
# 2018  730.908109  5.174886  11.661285   7.944653   8.066598  0.133571
# 2019  732.745721  4.059108  11.692726   7.964627   7.995409  0.175333
# 2020  859.491143  5.957742  13.786514   9.342295   9.322585  0.163386
# 2021  932.353205  5.132361  14.564622  10.134274  10.090291  0.180576
#
#         Vari_N  Vari_N-1  DesvPad_N  DesvPad_N-1       25%        50%  \
# 2000  1.657023  1.675232   1.287254     1.294308  6.182026   6.906514
# 2001  1.229151  1.242658   1.108671     1.114746  5.956269   6.825371
# 2002  1.240767  1.254402   1.113897     1.120001  6.115280   6.978982
# 2003  1.523532  1.540274   1.234314     1.241078  6.023312   6.954993
# 2004  1.390378  1.405657   1.179143     1.185604  6.280521   6.875969
# 2005  1.409307  1.424794   1.187143     1.193647  5.916391   6.694074
# 2006  1.348277  1.363093   1.161153     1.167516  5.839122   6.923224
# 2007  1.160166  1.172915   1.077110     1.083012  6.020694   7.021150
# 2008  1.649416  1.667541   1.284296     1.291333  6.429402   7.181707
# 2009  1.288117  1.302272   1.134952     1.141171  6.497818   7.031063
# 2010  1.366079  1.381091   1.168794     1.175198  6.468126   7.358026
# 2011  1.489981  1.506354   1.220648     1.227336  6.544573   7.406652
# 2012  1.439645  1.455465   1.199852     1.206427  6.591643   7.298473
# 2013  1.527669  1.544456   1.235989     1.242762  6.782929   7.558920
# 2014  1.284426  1.298541   1.133325     1.139535  6.846413   7.540442
# 2015  1.264185  1.278077   1.124360     1.130521  6.835102   7.452483
# 2016  1.516139  1.532800   1.231316     1.238063  7.183622   8.090344
# 2017  1.166864  1.179687   1.080215     1.086134  7.265909   7.848429
# 2018  1.160922  1.173679   1.077461     1.083365  7.358105   8.066598
# 2019  1.965215  1.986810   1.401861     1.409543  7.133513   7.995409
# 2020  2.320081  2.345576   1.523181     1.531527  8.372891   9.322585
# 2021  3.319901  3.356384   1.822060     1.832044  9.048225  10.090291
#
#             75%
# 2000   7.598632
# 2001   7.727270
# 2002   7.472015
# 2003   7.808452
# 2004   7.660738
# 2005   7.478515
# 2006   7.671703
# 2007   7.651106
# 2008   7.779017
# 2009   7.732257
# 2010   8.142662
# 2011   8.088498
# 2012   8.096956
# 2013   8.217558
# 2014   8.198289
# 2015   8.247430
# 2016   8.801621
# 2017   8.586468
# 2018   8.563498
# 2019   8.929147
# 2020  10.207520
# 2021  11.285963

# %% [markdown]
# # Grafico mostra media da taxa de mortalidade de 2000 - 2021

# %%
data = pd.DataFrame({'Mortalidade':media_ano})
data
data.plot()
plt.ylabel("taxa")
plt.show()
# Grafico mostra media da taxa de mortalidade de 2000 - 2020

# %%
def outilers(media, title):
    data = pd.DataFrame(data=media, columns=["Mortalidade"])
    data.boxplot()
    plt.title(title)
    plt.ylabel("taxa")
    plt.show()
    
    q1 = media.quantile(q=0.25)
    q3 = media.quantile(q=0.75)
    lim_inf = q1 - 1.5 * (q3-q1)
    lim_sup = q3 + 1.5 * (q3-q1)
    print(f"Limite Inferior: {lim_inf:,.3f}")
    print(f"Limite Superior: {lim_sup:,.3f}")
    
    outilers = [x for x in data.index if data.loc[x,"Mortalidade"] < lim_inf or data.loc[x,"Mortalidade"] > lim_sup]
    print(data)
    print(f"outilers: {outilers}")

# %%
def outilers_dataframe(media):
    data = pd.DataFrame(data=media, columns=["Mortalidade"])
    q1 = data.quantile(q=0.25)
    q3 = data.quantile(q=0.75)
    lim_inf = q1 - 1.5 * (q3-q1)
    lim_sup = q3 + 1.5 * (q3-q1)
    filtro = (data.Mortalidade < float(lim_inf)) | (data.Mortalidade > float(lim_sup))
    return data.loc[filtro]

# %% [markdown]
# # Box plot por municipios

# %%
outilers(media_ano, "Media por municipio")
# Out:
# Limite Inferior: 5.506
# Limite Superior: 9.176
#       Mortalidade
# 2000     6.789792
# 2001     6.799110
# 2002     6.870903
# 2003     6.906196
# 2004     6.874197
# 2005     6.753657
# 2006     6.808354
# 2007     6.929976
# 2008     7.138702
# 2009     7.075074
# 2010     7.271664
# 2011     7.370295
# 2012     7.339212
# 2013     7.501050
# 2014     7.553722
# 2015     7.586789
# 2016     7.944917
# 2017     7.870453
# 2018     7.944653
# 2019     7.964627
# 2020     9.342295
# 2021    10.134274
# outilers: ['2020', '2021']

# %% [markdown]
# # Mostra os outliers de municipios

# %%
outilers_dataframe(media_mun) # Mostra os outliers de municipios
# Out:
#            Mortalidade
# Município
# Macuco       10.670853

# %%
data = pd.DataFrame(data=media_ano, columns=["Mortalidade"])
data.quantile(q=0.25)
# Out:
# Mortalidade    6.882197
# Name: 0.25, dtype: float64

# %%
d = pd.DataFrame(data=media_mun, columns=["Mortalidade"])
d
# Out:
#                     Mortalidade
# Município
# Angra dos Reis         5.299367
# Aperibé                7.363242
# Araruama               7.905830
# Areal                  7.194039
# Armação dos Búzios     6.363618
# ...                         ...
# Três Rios              8.312456
# Valença                8.512180
# Varre-Sai              5.961292
# Vassouras              8.986956
# Volta Redonda          7.577701
#
# [92 rows x 1 columns]

# %%
outilers(media_ano, "Media por ano")
# Out:
# Limite Inferior: 5.506
# Limite Superior: 9.176
#       Mortalidade
# 2000     6.789792
# 2001     6.799110
# 2002     6.870903
# 2003     6.906196
# 2004     6.874197
# 2005     6.753657
# 2006     6.808354
# 2007     6.929976
# 2008     7.138702
# 2009     7.075074
# 2010     7.271664
# 2011     7.370295
# 2012     7.339212
# 2013     7.501050
# 2014     7.553722
# 2015     7.586789
# 2016     7.944917
# 2017     7.870453
# 2018     7.944653
# 2019     7.964627
# 2020     9.342295
# 2021    10.134274
# outilers: ['2020', '2021']

# %% [markdown]
# # Box plot por Ano

# %%
outilers_dataframe(media_ano) # Mostra os outliers de ano
# Out:
#       Mortalidade
# 2020     9.342295
# 2021    10.134274

# %% [markdown]
# **Parte 2**

# %%
def amostra_simples(x,fr, reposicao):
  if(reposicao == True):
    x_sample = x.sample(frac=fr, replace = True)
  else:
    x_sample = x.sample(frac=fr, replace = False)
  
  quantidade = x.count()
  media = x.mean()
  variancia = x.var()
  variancia_populacao = x.var(ddof=0)
  print("Média Original:", media)
  print("Variância Original:", variancia)
  print("Variância N-1 (População) Original:", variancia_populacao)
  print("Qunatidade Original:", quantidade)
  print("=======================================")
  quantidade = x_sample.count()
  media = x_sample.mean()
  variancia = x_sample.var()
  variancia_populacao = x_sample.var(ddof=0)
  print("Média Amostra: ", media)
  print("Variância Amostra: ", variancia)
  print("Variância N-1 (População) Amostra: ",variancia_populacao)
  print("Qunatidade Amostra: ", quantidade)

  tam_amostra = x_sample.count() 

  dp_populacao = x.std(ddof=0)

  nc=0.95
  z = abs(scipy.stats.norm.ppf((1 - nc)/2.))
  erro = z*dp_populacao/np.sqrt(tam_amostra)
  erro_padrao = dp_populacao/np.sqrt(tam_amostra)
  print("Erro Amostra", erro)
  print("Erro padrão", erro_padrao)
  data = pd.DataFrame(data=x_sample, columns=["Municipios"])
  return  data

# %%
df2 = amostra_simples(media_mun, 0.2, True)
df2
# Out:
# Média Original: 7.4895414844087425
# Variância Original: 1.0279466098732775
# Variância N-1 (População) Original: 1.0167732771572637
# Qunatidade Original: 92
# =======================================
# Média Amostra:  7.438712463224778
# Variância Amostra:  0.7956285581154598
# Variância N-1 (População) Amostra:  0.7514269715534899
# Qunatidade Amostra:  18
# Erro Amostra 0.4658261880299849
# Erro padrão 0.23767078972081246
#                     Municipios
# Município
# Itaboraí              7.540910
# São João de Meriti    7.987495
# Saquarema             7.803101
# Quatis                6.284347
# Cantagalo             8.176993
# Petrópolis            8.877004
# Areal                 7.194039
# São Fidélis           8.279342
# Barra Mansa           7.369862
# Porto Real            6.218223
# Aperibé               7.363242
# Bom Jardim            7.581228
# Casimiro de Abreu     6.040432
# Bom Jardim            7.581228
# Porto Real            6.218223
# São João da Barra     8.040964
# Seropédica            6.463186
# Petrópolis            8.877004

# %%
amostra_simples(media_mun, 0.8, True)
# Out:
# Média Original: 7.4895414844087425
# Variância Original: 1.0279466098732775
# Variância N-1 (População) Original: 1.0167732771572637
# Qunatidade Original: 92
# =======================================
# Média Amostra:  7.461075025042474
# Variância Amostra:  1.0303980594795226
# Variância N-1 (População) Amostra:  1.016473761378448
# Qunatidade Amostra:  74
# Erro Amostra 0.22974406071733336
# Erro padrão 0.11721851142649826
#                      Municipios
# Município
# São Gonçalo            7.145549
# Japeri                 6.674194
# São Pedro da Aldeia    6.237374
# Niterói                8.860678
# São Pedro da Aldeia    6.237374
# ...                         ...
# Teresópolis            7.896994
# Miguel Pereira         9.006394
# Cabo Frio              6.374826
# Cambuci                8.632100
# Cabo Frio              6.374826
#
# [74 rows x 1 columns]

# %%
amostra_simples(media_mun, 1, False)
# Out:
# Média Original: 7.4895414844087425
# Variância Original: 1.0279466098732775
# Variância N-1 (População) Original: 1.0167732771572637
# Qunatidade Original: 92
# =======================================
# Média Amostra:  7.4895414844087425
# Variância Amostra:  1.0279466098732775
# Variância N-1 (População) Amostra:  1.0167732771572637
# Qunatidade Amostra:  92
# Erro Amostra 0.2060469731739597
# Erro padrão 0.10512793847194742

# %% [markdown]
# **Parte 3**

# %%
def intervalo_confianca(nc, amostra, populacao):
    
  media_amostra = amostra.mean(numeric_only=True)[0]
  tam_amostra = amostra.count()[0]
  dp_populacao = populacao.std(ddof=0)
  z = abs(scipy.stats.norm.ppf((1 - nc)/2.))
  print("z: {:.2f}".format(z))
  print("Desvio Padrão População: ", dp_populacao)
  
  IC1 = media_amostra - z * dp_populacao/np.sqrt(tam_amostra)
  IC2 = media_amostra + z * dp_populacao/np.sqrt(tam_amostra)

  print("Intervalo de confianca:", [IC1, IC2])
  print("Limite Inferior: ", IC1)
  print("Limite Superior: ", IC2)
  print("Amplitude Intervalo {:.4f}".format(IC2-IC1))
  print("Nivel de Confiança: ", nc)

# %%
media_amostra = df2.mean(numeric_only=True)[0]
tam_amostra = df2.count()[0]
nc = 0.95
dp_populacao = media_mun.std(ddof=0)
z = abs(scipy.stats.norm.ppf((1 - nc)/2.))
print("z: {:.2f}".format(z))
print("Desvio Padrão População: ", dp_populacao)
IC1 = media_amostra - z*dp_populacao/np.sqrt(tam_amostra)
IC2 = media_amostra + z*dp_populacao/np.sqrt(tam_amostra)
print("----- Intervalo de Confiança ----")
print("Limite Inferior: ", IC1)
print("Limite Superior: ", IC2)
print("Amplitude Intervalo {:.4f}".format(IC2-IC1))
print("Nivel de Confiança: ", nc)
# Out:
# z: 1.96
# Desvio Padrão População:  1.0083517626092908
# ----- Intervalo de Confiança ----
# Limite Inferior:  6.768951437455048
# Limite Superior:  7.700603813515018
# Amplitude Intervalo 0.9317
# Nivel de Confiança:  0.95

# %%
amostra = amostra_simples(media_mun, 0.2, True)
# Out:
# Média Original: 7.4895414844087425
# Variância Original: 1.0279466098732775
# Variância N-1 (População) Original: 1.0167732771572637
# Qunatidade Original: 92
# =======================================
# Média Amostra:  7.7869692355638875
# Variância Amostra:  1.4022004596187434
# Variância N-1 (População) Amostra:  1.3243004340843687
# Qunatidade Amostra:  18
# Erro Amostra 0.4658261880299849
# Erro padrão 0.23767078972081246

# %%
intervalo_confianca(0.95, amostra, media_mun)
# Out:
# z: 1.96
# Desvio Padrão População:  1.0083517626092908
# Intervalo de confianca: [7.321143047533902, 8.252795423593872]
# Limite Inferior:  7.321143047533902
# Limite Superior:  8.252795423593872
# Amplitude Intervalo 0.9317
# Nivel de Confiança:  0.95

# %% [markdown]
# **Parte 4**

# %%
nc = 0.95
z = abs(scipy.stats.norm.ppf((1 - nc)/2.))
erro = z*dp_populacao/np.sqrt(tam_amostra)
erro_padrao = dp_populacao/np.sqrt(tam_amostra)
print("Erro Amostra", erro)
print("Erro padrão", erro_padrao)
print(tam_amostra)
print(z)
print(media_amostra)
# Out:
# Erro Amostra 0.4658261880299849
# Erro padrão 0.23767078972081246
# 18
# 1.959963984540054
# 7.234777625485033

# %%
amostra_simples(media_mun, 0.1, True)
# Out:
# Média Original: 7.4895414844087425
# Variância Original: 1.0279466098732775
# Variância N-1 (População) Original: 1.0167732771572637
# Qunatidade Original: 92
# =======================================
# Média Amostra:  7.294096764409845
# Variância Amostra:  0.977467581034415
# Variância N-1 (População) Amostra:  0.8688600720305911
# Qunatidade Amostra:  9
# Erro Amostra 0.6587777128205641
# Erro padrão 0.33611725420309696
#                       Municipios
# Município
# Paraty                  5.536688
# Arraial do Cabo         7.218169
# São João de Meriti      7.987495
# Miguel Pereira          9.006394
# São José de Ubá         6.962037
# Cachoeiras de Macacu    7.179349
# Pinheiral               6.374115
# Queimados               7.808294
# Mesquita                7.574330

# %%
amostra_simples(media_mun, 0.2, True)
# Out:
# Média Original: 7.4895414844087425
# Variância Original: 1.0279466098732775
# Variância N-1 (População) Original: 1.0167732771572637
# Qunatidade Original: 92
# =======================================
# Média Amostra:  7.2454149956766765
# Variância Amostra:  0.7539530912286804
# Variância N-1 (População) Amostra:  0.7120668083826426
# Qunatidade Amostra:  18
# Erro Amostra 0.4658261880299849
# Erro padrão 0.23767078972081246
#                        Municipios
# Município
# Nova Iguaçu              7.593292
# Quatis                   6.284347
# Mangaratiba              7.558931
# Campos dos Goytacazes    7.908164
# São Pedro da Aldeia      6.237374
# Rio das Flores           7.327539
# Trajano de Moraes        7.483108
# Rio das Flores           7.327539
# Itatiaia                 6.430593
# Angra dos Reis           5.299367
# São Pedro da Aldeia      6.237374
# Nova Iguaçu              7.593292
# Petrópolis               8.877004
# Bom Jardim               7.581228
# Cachoeiras de Macacu     7.179349
# São Gonçalo              7.145549
# São João da Barra        8.040964
# Três Rios                8.312456

# %%
amostra_simples(media_mun, 0.3, True)
# Out:
# Média Original: 7.4895414844087425
# Variância Original: 1.0279466098732775
# Variância N-1 (População) Original: 1.0167732771572637
# Qunatidade Original: 92
# =======================================
# Média Amostra:  7.325519770281265
# Variância Amostra:  1.0643667772064769
# Variância N-1 (População) Amostra:  1.0263536780205313
# Qunatidade Amostra:  28
# Erro Amostra 0.37349185658467277
# Erro padrão 0.190560571281273
#                              Municipios
# Município
# Casimiro de Abreu              6.040432
# Quatis                         6.284347
# Seropédica                     6.463186
# Valença                        8.512180
# Rio de Janeiro                 8.481361
# Barra do Piraí                 7.955486
# Duas Barras                    6.379096
# Cordeiro                       7.002696
# Tanguá                         6.566320
# São Sebastião do Alto          7.878777
# Tanguá                         6.566320
# Mendes                         9.253451
# Mangaratiba                    7.558931
# Cardoso Moreira                8.420598
# Casimiro de Abreu              6.040432
# Araruama                       7.905830
# Guapimirim                     6.669842
# Cabo Frio                      6.374826
# Carmo                          8.012262
# Teresópolis                    7.896994
# Bom Jardim                     7.581228
# Miguel Pereira                 9.006394
# Engenheiro Paulo de Frontin    8.599118
# Carmo                          8.012262
# Carapebus                      5.674532
# São José de Ubá                6.962037
# Carapebus                      5.674532
# Maricá                         7.341085

# %%
amostra_simples(media_mun, 0.5, True)
# Out:
# Média Original: 7.4895414844087425
# Variância Original: 1.0279466098732775
# Variância N-1 (População) Original: 1.0167732771572637
# Qunatidade Original: 92
# =======================================
# Média Amostra:  7.813562549813784
# Variância Amostra:  0.8287042910819218
# Variância N-1 (População) Amostra:  0.8106889804062278
# Qunatidade Amostra:  46
# Erro Amostra 0.2913944239485391
# Erro padrão 0.1486733563713523
#                              Municipios
# Município
# Barra Mansa                    7.369862
# Porciúncula                    7.522293
# Natividade                     8.596049
# Cantagalo                      8.176993
# Araruama                       7.905830
# Natividade                     8.596049
# São Pedro da Aldeia            6.237374
# Mendes                         9.253451
# São Pedro da Aldeia            6.237374
# Paracambi                      7.923069
# Belford Roxo                   7.049642
# Macuco                        10.670853
# São João da Barra              8.040964
# Natividade                     8.596049
# Duque de Caxias                7.324711
# São João de Meriti             7.987495
# Cachoeiras de Macacu           7.179349
# São Gonçalo                    7.145549
# São João de Meriti             7.987495
# Vassouras                      8.986956
# Porto Real                     6.218223
# São João da Barra              8.040964
# Laje do Muriaé                 8.630415
# Teresópolis                    7.896994
# Bom Jesus do Itabapoana        8.823158
# Silva Jardim                   6.926578
# Casimiro de Abreu              6.040432
# Paty do Alferes                7.630262
# Belford Roxo                   7.049642
# Santo Antônio de Pádua         8.374362
# São João da Barra              8.040964
# Resende                        6.586442
# Rio Bonito                     7.424763
# São Sebastião do Alto          7.878777
# Belford Roxo                   7.049642
# Cachoeiras de Macacu           7.179349
# Nilópolis                      9.202487
# Araruama                       7.905830
# Laje do Muriaé                 8.630415
# Conceição de Macabu            6.928696
# Engenheiro Paulo de Frontin    8.599118
# Queimados                      7.808294
# Cambuci                        8.632100
# Magé                           7.967570
# Volta Redonda                  7.577701
# Nova Iguaçu                    7.593292

# %% [markdown]
# ## Foi analisado quanto maior e a amostar, menor taxa de erro

# %% [markdown]
# # Questões para Aprimorar Pesquisa:

# %% [markdown]
# * O que elevou a taxa de mortalidade a longo do anos. Vimos que entre 2019 - 2021 teve alto aumento por passamos por pandemia. Mas quantos anos anteriores  ?
# * O que podemos fazer para melhor ?
# * Quais principais causa alta taxa desde 2010 ?

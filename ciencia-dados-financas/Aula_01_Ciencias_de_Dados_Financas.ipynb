# %% [markdown]
# # *Link de Estudo:*
# - https://investidoremvalor.com/formula-de-greenblatt/
# - https://sparkbyexamples.com/pandas/pandas-convert-column-to-int/
# - https://opencodecom.net/post/2021-05-07-fronteira-eficiente/

# %%
# Instalando o fundamentus
# !pip install fundamentus --upgrade --no-cache-dir
# Out:
# Collecting fundamentus
#   Downloading fundamentus-0.2.0-py3-none-any.whl (13 kB)
# Collecting requests-cache>=0.5.2
#   Downloading requests_cache-0.9.6-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 1.8 MB/s
# Requirement already satisfied: requests>=2.25.1 in /opt/conda/lib/python3.9/site-packages (from fundamentus) (2.26.0)
# Collecting tabulate>=0.8.7
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting lxml>=4.6.2
#   Downloading lxml-4.9.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (7.0 MB)
#      |████████████████████████████████| 7.0 MB 1.9 MB/s
# Requirement already satisfied: pandas>=1.1.5 in /opt/conda/lib/python3.9/site-packages (from fundamentus) (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.9/site-packages (from pandas>=1.1.5->fundamentus) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.9/site-packages (from pandas>=1.1.5->fundamentus) (2021.3)
# Requirement already satisfied: numpy>=1.17.3 in /opt/conda/lib/python3.9/site-packages (from pandas>=1.1.5->fundamentus) (1.20.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests>=2.25.1->fundamentus) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests>=2.25.1->fundamentus) (3.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.9/site-packages (from requests>=2.25.1->fundamentus) (2.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests>=2.25.1->fundamentus) (2022.9.24)
# Requirement already satisfied: attrs>=21.2 in /opt/conda/lib/python3.9/site-packages (from requests-cache>=0.5.2->fundamentus) (21.2.0)
# Collecting cattrs>=1.8
#   Downloading cattrs-22.2.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: appdirs>=1.4.4 in /opt/conda/lib/python3.9/site-packages (from requests-cache>=0.5.2->fundamentus) (1.4.4)
# Collecting url-normalize>=1.4
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Collecting exceptiongroup
#   Downloading exceptiongroup-1.0.0rc9-py3-none-any.whl (12 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas>=1.1.5->fundamentus) (1.16.0)
# Installing collected packages: exceptiongroup, url-normalize, cattrs, tabulate, requests-cache, lxml, fundamentus
# Successfully installed cattrs-22.2.0 exceptiongroup-1.0.0rc9 fundamentus-0.2.0 lxml-4.9.1 requests-cache-0.9.6 tabulate-0.9.0 url-normalize-1.4.3

# %%
# Instalando o yahoo finance
# !pip install yfinance --upgrade --no-cache-dir
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.80-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: lxml>=4.5.1 in /opt/conda/lib/python3.9/site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: requests>=2.26 in /opt/conda/lib/python3.9/site-packages (from yfinance) (2.26.0)
# Requirement already satisfied: appdirs>=1.4.4 in /opt/conda/lib/python3.9/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pandas>=0.24.0 in /opt/conda/lib/python3.9/site-packages (from yfinance) (1.3.4)
# Requirement already satisfied: numpy>=1.15 in /opt/conda/lib/python3.9/site-packages (from yfinance) (1.20.3)
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.9/site-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.9/site-packages (from pandas>=0.24.0->yfinance) (2021.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests>=2.26->yfinance) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests>=2.26->yfinance) (2022.9.24)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.9/site-packages (from requests>=2.26->yfinance) (2.0.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests>=2.26->yfinance) (3.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.16.0)
# Installing collected packages: multitasking, yfinance
# Successfully installed multitasking-0.0.11 yfinance-0.1.80

# %%
import fundamentus
import matplotlib.pyplot as plt
import yfinance as yf
# Out:
# 2022-10-25 00:40:05,054 [logging.log_init] INFO: LOGLEVEL=INFO

# %%
df = fundamentus.get_resultado()

# %%
# df_roe['liq2m'] = df_roe['liq2m'].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 969 entries, AALR3 to YDUQ3
# Data columns (total 20 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   cotacao   969 non-null    float64
#  1   pl        969 non-null    float64
#  2   pvp       969 non-null    float64
#  3   psr       969 non-null    float64
#  4   dy        969 non-null    float64
#  5   pa        969 non-null    float64
#  6   pcg       969 non-null    float64
#  7   pebit     969 non-null    float64
#  8   pacl      969 non-null    float64
#  9   evebit    969 non-null    float64
#  10  evebitda  969 non-null    float64
#  11  mrgebit   969 non-null    float64
#  12  mrgliq    969 non-null    float64
#  13  roic      969 non-null    float64
#  14  roe       969 non-null    float64
#  15  liqc      969 non-null    float64
#  16  liq2m     969 non-null    float64
#  17  patrliq   969 non-null    float64
#  18  divbpatr  969 non-null    float64
#  19  c5y       969 non-null    float64
# dtypes: float64(20)
# memory usage: 159.0+ KB

# %%
df.head()
# Out:
# Multiples  cotacao      pl   pvp    psr      dy     pa    pcg  pebit   pacl  \
# papel
# AALR3        20.87  -44.71  2.16  2.224  0.0000  0.959 -26.56  33.30  -2.62
# ABCB3         0.00    0.00  0.00  0.000  0.0000  0.000   0.00   0.00   0.00
# ABCB4        21.32    6.92  0.98  0.000  0.0600  0.000   0.00   0.00   0.00
# ABEV3        14.83   17.25  2.71  3.036  0.0407  1.710  53.81  15.07 -21.61
# ABYA3         4.91 -214.80  1.76  2.055  0.0000  0.527   1.98  19.96  -2.75
#
# Multiples  evebit  evebitda  mrgebit  mrgliq    roic     roe  liqc  \
# papel
# AALR3       40.97     15.91   0.0668 -0.0422  0.0330 -0.0482  0.83
# ABCB3        0.00      0.00   0.0000  0.0000  0.0000  0.1418  0.00
# ABCB4        0.00      0.00   0.0000  0.0000  0.0000  0.1418  0.00
# ABEV3       14.26     10.66   0.2015  0.1827  0.1533  0.1570  1.13
# ABYA3       33.67     33.67   0.1029 -0.0096  0.0278 -0.0082  2.09
#
# Multiples        liq2m       patrliq  divbpatr     c5y
# papel
# AALR3        7099020.0  1.145370e+09      0.71  0.0086
# ABCB3              0.0  4.910570e+09      0.00  0.2080
# ABCB4       16950500.0  4.910570e+09      0.00  0.2080
# ABEV3      393035000.0  8.626310e+10      0.04  0.1195
# ABYA3              0.0  2.920600e+08      1.31  0.1641

# %%
print(df.columns)
# Out:
# Index(['cotacao', 'pl', 'pvp', 'psr', 'dy', 'pa', 'pcg', 'pebit', 'pacl',
#        'evebit', 'evebitda', 'mrgebit', 'mrgliq', 'roic', 'roe', 'liqc',
#        'liq2m', 'patrliq', 'divbpatr', 'c5y'],
#       dtype='object', name='Multiples')

# %%
df = df.loc[df.liq2m > 0]

# %%
df.reset_index()
# Out:
# Multiples  papel  cotacao        pl   pvp      psr      dy       pa    pcg  \
# 0          AALR3    20.87    -44.71  2.16    2.224  0.0000    0.959 -26.56
# 1          ABCB4    21.32      6.92  0.98    0.000  0.0600    0.000   0.00
# 2          ABEV3    14.83     17.25  2.71    3.036  0.0407    1.710  53.81
# 3          ADHM3     1.56     -4.09 -1.29  770.924  0.0000  105.126  -1.43
# 4          AERI3     2.02  30955.00  1.60    0.643  0.0102    0.463   1.18
# ..           ...      ...       ...   ...      ...     ...      ...    ...
# 465        WHRL4     5.54     10.17  3.63    0.737  0.0781    1.016  16.78
# 466        WIZS3     7.75      9.85  3.24    1.490  0.0759    0.635  -8.85
# 467        WLMM3    22.49      8.10  1.42    0.528  0.0360    1.167   2.81
# 468        WLMM4    28.50     10.26  1.80    0.669  0.0312    1.478   3.56
# 469        YDUQ3    13.13    374.52  1.29    0.907  0.0096    0.411   3.80
#
# Multiples  pebit    pacl  ...  evebitda   mrgebit    mrgliq    roic     roe  \
# 0          33.30   -2.62  ...     15.91    0.0668   -0.0422  0.0330 -0.0482
# 1           0.00    0.00  ...      0.00    0.0000    0.0000  0.0000  0.1418
# 2          15.07  -21.61  ...     10.66    0.2015    0.1827  0.1533  0.1570
# 3          -5.69   -1.27  ...     -5.81 -135.4850 -188.6060  5.2170  0.3147
# 4           8.75   -8.59  ...     10.45    0.0735    0.0000  0.0966  0.0001
# ..           ...     ...  ...       ...       ...       ...     ...     ...
# 465         9.86 -199.66  ...      8.12    0.0748    0.0726  0.2195  0.3569
# 466         3.70   -1.75  ...      3.24    0.4021    0.2118  0.2012  0.3289
# 467         8.16    3.55  ...      7.00    0.0647    0.0652  0.1710  0.1750
# 468        10.34    4.49  ...      9.10    0.0647    0.0652  0.1710  0.1750
# 469         7.96   -1.02  ...      6.66    0.1139    0.0025  0.0621  0.0035
#
# Multiples  liqc         liq2m       patrliq  divbpatr     c5y
# 0          0.83  7.099020e+06  1.145370e+09      0.71  0.0086
# 1          0.00  1.695050e+07  4.910570e+09      0.00  0.2080
# 2          1.13  3.930350e+08  8.626310e+10      0.04  0.1195
# 3          0.00  2.064000e+03 -1.977600e+07      0.00  0.4348
# 4          2.49  9.732420e+06  9.673940e+08      1.71  0.0000
# ..          ...           ...           ...       ...     ...
# 465        1.09  5.551950e+04  2.293190e+09      0.47  0.1307
# 466        0.71  8.163420e+06  3.827010e+08      0.61  0.1281
# 467        5.59  8.655100e+02  5.777790e+08      0.02  0.2890
# 468        5.59  2.664800e+04  5.777790e+08      0.02  0.2890
# 469        1.64  7.487840e+07  3.137430e+09      1.80  0.0632
#
# [470 rows x 21 columns]

# %%
df_roe = df.sort_values("roe", ascending=False).copy()
df_roe.insert(0, 'number_roe', range(1, 1 + len(df_roe)))
df_roe = df_roe.sort_values("pl", ascending=False)
df_roe.insert(0, 'number_pl', range(1, 1 + len(df_roe)))
df_roe.reset_index(inplace=True)
df_roe["formula"] = df_roe["number_roe"] + df_roe["number_pl"]

# %%
df_roe.sort_values("formula", ascending=False).head(10)
# Out:
# Multiples  papel  number_pl  number_roe  cotacao     pl   pvp    psr     dy  \
# 458        ORVR3        459         434    42.16 -56.90  6.92  5.969  0.000
# 444        SMFT3        445         431    15.55 -20.70  2.21  3.958  0.000
# 410        BIOM3        411         464     6.60  -5.26  3.31  4.519  0.000
# 459        PDTC3        460         414     4.10 -60.26  2.69  0.930  0.000
# 409        BAHI3        410         463    13.83  -4.41  2.46  1.052  0.000
# 405        CVCB3        406         467     6.32  -3.58  3.57  1.583  0.000
# 435        IFCM3        436         436     5.65 -13.84  1.74  3.005  0.000
# 454        AALR3        455         416    20.87 -44.71  2.16  2.224  0.000
# 463        RAIL3        464         407    19.30 -97.62  2.43  4.391  0.001
# 451        RRRP3        452         418    40.23 -36.99  2.10  6.696  0.000
#
# Multiples     pa     pcg  ...  mrgebit  mrgliq    roic     roe  liqc  \
# 458        1.822   29.19  ...   0.2026 -0.0912  0.0657 -0.1217  1.40
# 444        0.843    4.99  ...  -0.0507 -0.1902 -0.0148 -0.1066  2.27
# 410        1.270    6.04  ...  -0.7050 -0.8598 -0.2715 -0.6303  2.03
# 459        0.680    1.98  ...   0.0435 -0.0154  0.0483 -0.0446  1.89
# 409        0.515   -2.56  ...  -0.0643 -0.2503 -0.0322 -0.5584  0.22
# 405        0.368   -2.16  ...  -0.1631 -0.4437 -0.0520 -0.9970  0.78
# 435        0.670  -17.43  ...  -0.0960 -0.2172 -0.0286 -0.1258  0.90
# 454        0.959  -26.56  ...   0.0668 -0.0422  0.0330 -0.0482  0.83
# 463        0.795    8.36  ...   0.2037 -0.0456  0.0435 -0.0249  1.85
# 451        1.362 -129.48  ...   0.3722 -0.2090  0.0841 -0.0568  0.93
#
# Multiples        liq2m       patrliq  divbpatr     c5y  formula
# 458         17325400.0  4.353900e+08      1.35  0.3258      893
# 444         23260100.0  4.131640e+09      0.73  0.1911      876
# 410            75443.8  1.464820e+08      1.18  4.1107      875
# 459           264458.0  1.196980e+08      1.00  2.8108      874
# 409           138187.0  1.336750e+08      0.94  0.7482      873
# 405        115786000.0  4.913910e+08      1.81 -0.1584      873
# 435          6788590.0  1.182990e+09      0.49  0.0000      872
# 454          7099020.0  1.145370e+09      0.71  0.0086      871
# 463        242310000.0  1.474590e+10      1.14  0.0642      871
# 451        164269000.0  3.879970e+09      0.03  0.0000      870
#
# [10 rows x 24 columns]

# %%
df_acoes = df_roe.sort_values("formula", ascending=False).head(7)[["papel","number_roe", "number_pl", "formula"]]

# %%
df_acoes
# Out:
# Multiples  papel  number_roe  number_pl  formula
# 458        ORVR3         434        459      893
# 444        SMFT3         431        445      876
# 410        BIOM3         464        411      875
# 459        PDTC3         414        460      874
# 409        BAHI3         463        410      873
# 405        CVCB3         467        406      873
# 435        IFCM3         436        436      872

# %%
codigos = df_acoes.iloc[4]
codigo_especifico = codigos[0]
print(codigo_especifico)
codigo = [str(codigo_especifico+'.SA')]
print(codigo[0])
# Out:
# BAHI3
# BAHI3.SA

# %%
df_grafico = yf.download(codigo[0], 
                 start='2021-08-01', 
                 end='2021-12-01',
                 group_by="ticker"); # ";" serve para não exibir os dados
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df_grafico
# Out:
#               Open    High    Low  Close  Adj Close  Volume
# Date
# 2021-08-02  15.960  15.960  15.96  15.96      15.96       0
# 2021-08-03  15.602  15.602  15.60  15.60      15.60    2500
# 2021-08-04  15.600  15.600  15.60  15.60      15.60       0
# 2021-08-05  15.600  15.600  15.60  15.60      15.60       0
# 2021-08-06  16.000  16.000  16.00  16.00      16.00     500
# ...            ...     ...    ...    ...        ...     ...
# 2021-11-24  13.400  13.730  13.40  13.73      13.73    2200
# 2021-11-25  13.860  13.890  13.47  13.60      13.60    4100
# 2021-11-26  13.400  13.890  13.40  13.89      13.89    2200
# 2021-11-29  13.890  13.890  13.62  13.85      13.85    1300
# 2021-11-30  13.880  13.880  13.78  13.78      13.78     500
#
# [83 rows x 6 columns]

# %%
plt.figure(figsize=(16, 8))
plt.title("Preço da Ação")
plt.xlabel("Período")
plt.ylabel("Preço de Fechamento")
plt.plot(df_grafico['Close'])
plt.show()

# %%
codigos = [str(codigo+'.SA') for codigo in df_acoes.iloc[:,0].to_numpy()]
codigos
# Out:
# ['ORVR3.SA',
#  'SMFT3.SA',
#  'BIOM3.SA',
#  'PDTC3.SA',
#  'BAHI3.SA',
#  'CVCB3.SA',
#  'IFCM3.SA']

# %%
codigos.append('^BVSP')
codigos
# Out:
# ['ORVR3.SA',
#  'SMFT3.SA',
#  'BIOM3.SA',
#  'PDTC3.SA',
#  'BAHI3.SA',
#  'CVCB3.SA',
#  'IFCM3.SA',
#  '^BVSP']

# %%
tickers = codigos
df = yf.download(tickers, 
                 start='2021-08-01', 
                 end='2021-12-01',
                 group_by="ticker");
# Out:
# [*********************100%***********************]  7 of 7 completed

# %%
df['BIOM3.SA']['Close']
# Out:
# Date
# 2021-08-02    14.90
# 2021-08-03    14.97
# 2021-08-04    14.50
# 2021-08-05    14.52
# 2021-08-06    14.50
#               ...
# 2021-11-24    12.80
# 2021-11-25    13.05
# 2021-11-26    13.00
# 2021-11-29    12.80
# 2021-11-30    13.00
# Name: Close, Length: 83, dtype: float64

# %%
df['SMFT3.SA']['Close']
# Out:
# Date
# 2021-08-02    27.799999
# 2021-08-03    28.040001
# 2021-08-04    28.400000
# 2021-08-05    27.799999
# 2021-08-06    28.200001
#                 ...
# 2021-11-24    20.629999
# 2021-11-25    21.280001
# 2021-11-26    19.450001
# 2021-11-29    18.870001
# 2021-11-30    18.090000
# Name: Close, Length: 83, dtype: float64

# %%
import pandas as pd
ativos = pd.DataFrame()
for ativo in tickers:
  ativos[ativo] = df[ativo]['Close']

# %%
ativos
# Out:
#              ORVR3.SA   SMFT3.SA  BIOM3.SA  PDTC3.SA  BAHI3.SA   CVCB3.SA  \
# Date
# 2021-08-02  26.000000  27.799999     14.90      5.70     15.96  21.850000
# 2021-08-03  26.370001  28.040001     14.97      5.79     15.60  21.590000
# 2021-08-04  26.000000  28.400000     14.50      5.69     15.60  20.940001
# 2021-08-05  25.299999  27.799999     14.52      5.65     15.60  20.469999
# 2021-08-06  25.600000  28.200001     14.50      5.68     16.00  20.570000
# ...               ...        ...       ...       ...       ...        ...
# 2021-11-24  25.430000  20.629999     12.80      4.90     13.73  15.730000
# 2021-11-25  25.150000  21.280001     13.05      4.99     13.60  16.809999
# 2021-11-26  24.400000  19.450001     13.00      4.85     13.89  14.950000
# 2021-11-29  24.200001  18.870001     12.80      5.20     13.85  14.550000
# 2021-11-30  22.549999  18.090000     13.00      4.85     13.78  13.620000
#
#              IFCM3.SA     ^BVSP
# Date
# 2021-08-02  19.590000  122516.0
# 2021-08-03  19.200001  123577.0
# 2021-08-04  18.860001  121801.0
# 2021-08-05  20.170000  121633.0
# 2021-08-06  20.299999  122810.0
# ...               ...       ...
# 2021-11-24  14.890000  104514.0
# 2021-11-25  15.490000  105811.0
# 2021-11-26  15.200000  102224.0
# 2021-11-29  15.400000  102814.0
# 2021-11-30  14.430000  101915.0
#
# [83 rows x 8 columns]

# %%
ativos.iloc[:,0:7].plot(figsize = (16,8), grid = True) 
plt.title("Cotação x tempo", fontsize = 25)
plt.xlabel("Período")
plt.ylabel("Preço de Fechamento")
plt.show()

# %%
for acao in tickers:
  serie = df[acao, 'Close']
  serie.plot()

plt.title("Cotação x tempo", fontsize = 25)
# Legendas
plt.legend(loc='lower left')
# plt.legend(loc=2)
# plt.legend(loc='best')
plt.figure();

# %%
df_pl = df.sort_values("pl", ascending=False).copy()
df_roe.reset_index(inplace=True)
df_roe.insert(0, 'number', range(1, 1 + len(df_roe)))
x = df_roe[['papel','number']]
x
# Out:
# Multiples   papel  number
# 0           AERI3       1
# 1          BBTG12       2
# 2           LIGT3       3
# 3           CALI4       4
# 4           UBBR3       5
# ..            ...     ...
# 964         MLFT4     965
# 965         MGLU3     966
# 966         PLDN4     967
# 967         TRAD3     968
# 968         GNDI3     969
#
# [969 rows x 2 columns]

# %%
data = df
data.loc["AALR3", "cotacao"]
# Out:
# 20.87

# %%
data.reset_index(drop=True, inplace=True)

# %%
data.head(10)
data.cotacao
# Out:
# 0      20.87
# 1       0.00
# 2      21.32
# 3      14.83
# 4       4.91
#        ...
# 964    22.49
# 965    28.50
# 966    25.39
# 967    67.00
# 968    13.13
# Name: cotacao, Length: 969, dtype: float64

# %%
import fundamentus
df = fundamentus.get_papel('WEGE3')
# Out:
# 2022-10-15 18:38:39,455 [detalhes.get_papel] INFO: detalhes: call: get..._papel()

# %%
import pandas as pd
data = pd.DataFrame(data=df)

# %%
data.dtypes
# Out:
# Papel                     object
# Tipo                      object
# Empresa                   object
# Setor                     object
# Subsetor                  object
# Cotacao                   object
# Data_ult_cot              object
# Min_52_sem                object
# Max_52_sem                object
# Vol_med_2m                object
# Valor_de_mercado           int64
# Valor_da_firma             int64
# Ult_balanco_processado    object
# Nro_Acoes                 object
# PL                        object
# PVP                       object
# PEBIT                     object
# PSR                       object
# PAtivos                   object
# PCap_Giro                 object
# PAtiv_Circ_Liq            object
# Div_Yield                 object
# EV_EBITDA                 object
# EV_EBIT                   object
# Cres_Rec_5a               object
# LPA                       object
# VPA                       object
# Marg_Bruta                object
# Marg_EBIT                 object
# Marg_Liquida              object
# EBIT_Ativo                object
# ROIC                      object
# ROE                       object
# Liquidez_Corr             object
# Div_Br_Patrim             object
# Giro_Ativos               object
# Ativo                     object
# Disponibilidades          object
# Ativo_Circulante          object
# Div_Bruta                 object
# Div_Liquida               object
# Patrim_Liq                object
# Receita_Liquida_12m       object
# EBIT_12m                  object
# Lucro_Liquido_12m         object
# Receita_Liquida_3m        object
# EBIT_3m                   object
# Lucro_Liquido_3m          object
# dtype: object

# %%
data['Lucro_Liquido_12m'] = data['Lucro_Liquido_12m'].astype('int')
data['Patrim_Liq'] = data['Patrim_Liq'].astype('int')
data['PL'] = data['PL'].astype('float') / 100

# %%
#  ROE =  Lucro Liquido do Ano / Patrimonio Liquido
def get_roe(data):
    return data["Lucro_Liquido_12m"]/data["Patrim_Liq"]

# %%
get_roe(data)
# Out:
# WEGE3    0.264192
# dtype: float64

# %%
data.PL + get_roe(data)
# Out:
# WEGE3    39.184192
# dtype: float64

# %%
data.PL
# Out:
# WEGE3    38.92
# Name: PL, dtype: float64

# %% [markdown]
# # **Fronteira Eficiente estimada de Ativos**

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ## **Selecionando ativos da carteira.**

# %%
codigos = [str(codigo+'.SA') for codigo in df_acoes.iloc[:,0].to_numpy()]
codigos
# Out:
# ['ORVR3.SA',
#  'SMFT3.SA',
#  'BIOM3.SA',
#  'PDTC3.SA',
#  'BAHI3.SA',
#  'CVCB3.SA',
#  'IFCM3.SA']

# %% [markdown]
# ## **Criando um dataframe que vai conter as cotações diárias dessas ações.**

# %%
codigos = ['ABEV3.SA', 'EQTL3.SA', 'LREN3.SA', 'CIEL3.SA', 'RADL3.SA', 'RENT3.SA', 'MDIA3.SA', 'WEGE3.SA', 'EZTC3.SA', 'FLRY3.SA']
tickers = codigos
df = yf.download(tickers, 
                 start='2014-01-01', 
                 end='2021-12-01',
                 group_by="ticker");
# Out:
# [*********************100%***********************]  10 of 10 completed

# %%
ativos = pd.DataFrame()
for ativo in codigos:
  ativos[ativo] = df[ativo]['Close']

# %%
ativos
# Out:
#              ABEV3.SA   EQTL3.SA   LREN3.SA   CIEL3.SA   RADL3.SA   RENT3.SA  \
# Date
# 2014-01-02  17.388399   4.558000   9.674918  19.129049   3.030000   9.901738
# 2014-01-03  17.018435   4.482000   9.811023  19.372107   2.984000  10.098261
# 2014-01-06  16.798454   4.434000   9.673278  19.395254   3.034000   9.889644
# 2014-01-07  17.328405   4.434000   9.865137  19.618055   3.050000   9.823129
# 2014-01-08  17.498390   4.452000   9.847099  19.646990   3.050000   9.856386
# ...               ...        ...        ...        ...        ...        ...
# 2021-11-24  17.100000  23.219999  30.610001   2.170000  23.450001  52.869999
# 2021-11-25  17.230000  23.150000  30.770000   2.170000  23.500000  54.110001
# 2021-11-26  16.690001  22.770000  29.360001   2.080000  22.660000  52.360001
# 2021-11-29  16.340000  22.780001  28.940001   2.070000  22.610001  52.250000
# 2021-11-30  16.059999  22.570000  28.450001   2.070000  22.379999  51.110001
#
#              MDIA3.SA   WEGE3.SA   EZTC3.SA   FLRY3.SA
# Date
# 2014-01-02  32.900002   4.497041  20.519358   9.200000
# 2014-01-03  33.963333   4.455621  20.578049   9.200000
# 2014-01-06  33.500000   4.479289  20.534031   9.300000
# 2014-01-07  33.666664   4.476331  20.622065   9.300000
# 2014-01-08  33.333332   4.399408  20.541367   9.405000
# ...               ...        ...        ...        ...
# 2021-11-24  28.520000  33.529999  18.120001  18.590000
# 2021-11-25  28.780001  33.799999  19.129999  18.950001
# 2021-11-26  28.280001  32.689999  18.590000  18.020000
# 2021-11-29  28.100000  32.410000  18.330000  17.879999
# 2021-11-30  27.780001  32.230000  18.139999  17.469999
#
# [1965 rows x 10 columns]

# %% [markdown]
# ## **Visualizando os preços.**

# %%
ativos.plot(figsize = (10,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## **Visualizando o dataframe.**

# %%
ativos.head()
# Out:
#              ABEV3.SA  EQTL3.SA  LREN3.SA   CIEL3.SA  RADL3.SA   RENT3.SA  \
# Date
# 2014-01-02  17.388399     4.558  9.674918  19.129049     3.030   9.901738
# 2014-01-03  17.018435     4.482  9.811023  19.372107     2.984  10.098261
# 2014-01-06  16.798454     4.434  9.673278  19.395254     3.034   9.889644
# 2014-01-07  17.328405     4.434  9.865137  19.618055     3.050   9.823129
# 2014-01-08  17.498390     4.452  9.847099  19.646990     3.050   9.856386
#
#              MDIA3.SA  WEGE3.SA   EZTC3.SA  FLRY3.SA
# Date
# 2014-01-02  32.900002  4.497041  20.519358     9.200
# 2014-01-03  33.963333  4.455621  20.578049     9.200
# 2014-01-06  33.500000  4.479289  20.534031     9.300
# 2014-01-07  33.666664  4.476331  20.622065     9.300
# 2014-01-08  33.333332  4.399408  20.541367     9.405

# %% [markdown]
# ## **Calculando retorno diário dos papéis e tratando os dados.**

# %%
retorno_diario = ativos.pct_change()
retorno_diario.head()
# Out:
#             ABEV3.SA  EQTL3.SA  LREN3.SA  CIEL3.SA  RADL3.SA  RENT3.SA  \
# Date
# 2014-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2014-01-03 -0.021277 -0.016674  0.014068  0.012706 -0.015182  0.019847
# 2014-01-06 -0.012926 -0.010709 -0.014040  0.001195  0.016756 -0.020659
# 2014-01-07  0.031548  0.000000  0.019834  0.011487  0.005274 -0.006726
# 2014-01-08  0.009810  0.004060 -0.001828  0.001475  0.000000  0.003386
#
#             MDIA3.SA  WEGE3.SA  EZTC3.SA  FLRY3.SA
# Date
# 2014-01-02       NaN       NaN       NaN       NaN
# 2014-01-03  0.032320 -0.009211  0.002860   0.00000
# 2014-01-06 -0.013642  0.005312 -0.002139   0.01087
# 2014-01-07  0.004975 -0.000660  0.004287   0.00000
# 2014-01-08 -0.009901 -0.017184 -0.003913   0.01129

# %%
retorno_diario = retorno_diario.iloc[1:]
retorno_diario.head()
# Out:
#             ABEV3.SA  EQTL3.SA  LREN3.SA  CIEL3.SA  RADL3.SA  RENT3.SA  \
# Date
# 2014-01-03 -0.021277 -0.016674  0.014068  0.012706 -0.015182  0.019847
# 2014-01-06 -0.012926 -0.010709 -0.014040  0.001195  0.016756 -0.020659
# 2014-01-07  0.031548  0.000000  0.019834  0.011487  0.005274 -0.006726
# 2014-01-08  0.009810  0.004060 -0.001828  0.001475  0.000000  0.003386
# 2014-01-09 -0.023429  0.010782 -0.033139 -0.007364 -0.036066 -0.041411
#
#             MDIA3.SA  WEGE3.SA  EZTC3.SA  FLRY3.SA
# Date
# 2014-01-03  0.032320 -0.009211  0.002860  0.000000
# 2014-01-06 -0.013642  0.005312 -0.002139  0.010870
# 2014-01-07  0.004975 -0.000660  0.004287  0.000000
# 2014-01-08 -0.009901 -0.017184 -0.003913  0.011290
# 2014-01-09 -0.018400 -0.018157 -0.021429 -0.013291

# %% [markdown]
# ## **Calculando o retorno anual.**

# %%
retorno_anual = retorno_diario.mean()*250

# %% [markdown]
# ## **Matriz de covariância.**

# %%
cov_diario = retorno_diario.cov()
cov_diario
# Out:
#           ABEV3.SA  EQTL3.SA  LREN3.SA  CIEL3.SA  RADL3.SA  RENT3.SA  \
# ABEV3.SA  0.000303  0.000116  0.000182  0.000180  0.000119  0.000176
# EQTL3.SA  0.000116  0.000307  0.000199  0.000178  0.000106  0.000209
# LREN3.SA  0.000182  0.000199  0.000558  0.000249  0.000184  0.000368
# CIEL3.SA  0.000180  0.000178  0.000249  0.000757  0.000150  0.000278
# RADL3.SA  0.000119  0.000106  0.000184  0.000150  0.000395  0.000187
# RENT3.SA  0.000176  0.000209  0.000368  0.000278  0.000187  0.000711
# MDIA3.SA  0.000132  0.000118  0.000178  0.000182  0.000115  0.000205
# WEGE3.SA  0.000135  0.000127  0.000187  0.000179  0.000147  0.000216
# EZTC3.SA  0.000189  0.000240  0.000373  0.000276  0.000175  0.000394
# FLRY3.SA  0.000112  0.000135  0.000206  0.000158  0.000112  0.000208
#
#           MDIA3.SA  WEGE3.SA  EZTC3.SA  FLRY3.SA
# ABEV3.SA  0.000132  0.000135  0.000189  0.000112
# EQTL3.SA  0.000118  0.000127  0.000240  0.000135
# LREN3.SA  0.000178  0.000187  0.000373  0.000206
# CIEL3.SA  0.000182  0.000179  0.000276  0.000158
# RADL3.SA  0.000115  0.000147  0.000175  0.000112
# RENT3.SA  0.000205  0.000216  0.000394  0.000208
# MDIA3.SA  0.000454  0.000159  0.000237  0.000138
# WEGE3.SA  0.000159  0.000445  0.000211  0.000125
# EZTC3.SA  0.000237  0.000211  0.000783  0.000210
# FLRY3.SA  0.000138  0.000125  0.000210  0.000419

# %%
cov_anual = cov_diario*250

# %% [markdown]
# ## **Aqui vamos criar 200 mil portfólios fictícios com esses papéis.**

# %%
port_returns = []
port_volatility = []
stock_weights = []

# %% [markdown]
# ## **Vamos passar os parâmetros de simulação.**

# %%
num_assets = len(codigos)
num_portfolios = 200000

# %% [markdown]
# ## **Vamos usar a função random para criar 10 pesos aleatórios.**

# %%
peso = np.random.random(num_assets)
peso /= np.sum(peso)
peso
np.sum(peso)
for single_portfolio in range(num_portfolios):
    weights = np.random.random(num_assets)
    weights /= np.sum(weights)
    returns = np.dot(weights, retorno_anual)
    volatility = np.sqrt(np.dot(weights.T, np.dot(cov_anual, weights)))
    port_returns.append(returns)
    port_volatility.append(volatility)
    stock_weights.append(weights)
    portfolio = {'Retornos': port_returns, 'Volatilidade': port_volatility}
for counter,symbol in enumerate(ativos):
    portfolio[symbol+' peso'] = [weight[counter] for weight in stock_weights]
df = pd.DataFrame(portfolio)
df.head()
retornos = df.sort_values(by = ['Retornos'], ascending = False)
retornos.head()
plt.style.use('seaborn')

df.plot.scatter(x = 'Volatilidade', y = 'Retornos', figsize = (10,10), grid = True)

plt.xlabel('Volatilidade')

plt.ylabel('Retornos Esperados')

plt.title('Fronteira Eficiente')

plt.show()

# %%
retorno_max = retornos.iloc[:1]
retorno_max = retorno_max.drop(['Retornos', 'Volatilidade'], axis = 1)
retorno_max
pesos = np.array(retorno_max)
pesos
retorno_carteira = retorno_diario*pesos

# %% [markdown]
# ## **Plotando o retorno da carteira.**

# %%
retorno_carteira.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## **Retorno acumulado.**

# %%
returns_acm = (1 + retorno_carteira).cumprod()
returns_acm.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## **Importando dados do IBOV para Benchmark.**

# %%
ibov = yf.download('^BVSP', 
                 start='2014-01-01', 
                 end='2021-12-01',
                 group_by="ticker")['Adj Close']
type(ibov)
pd.core.series.Series
ibov_retornos = ibov.pct_change()
ibov_retornos_acm = (1 + ibov_retornos).cumprod()
pd.DataFrame(ibov_retornos_acm)
novo_df = pd.merge(pd.DataFrame(ibov_retornos_acm), pd.DataFrame(returns_acm, columns = ['Minha Carteira']), how = 'inner', on = 'Date')
novo_df.rename(columns = {'Adj Close': 'IBOV'}, inplace = True)
novo_df.head()
novo_df.plot()
# Out:
# [*********************100%***********************]  1 of 1 completed
# <AxesSubplot:xlabel='Date'>
